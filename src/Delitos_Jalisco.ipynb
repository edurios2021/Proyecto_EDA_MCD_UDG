# %% [markdown]
# # <span style="color:blue"> Análisis Exploratorio de datos (EDA)  - Seguridad en Jalisco </span>

# %% [markdown]
# ## Contenido

# %% [markdown]
#  + Fuente de los datos
#  + Descripción de los datos
#  + Missing Values
#  + Limpieza de los datos
#  + Visualización de los datos
#  + Comentarios finales
#  + Referencias

# %% [markdown]
# ## 1. Fuente de Datos

# %% [markdown]
# <div style="text-align: justify"> Los datos se presentan de manera estructurada en un archivo csv
#  y son extráidos de la sección de laboratorio de datos del portal web
#  Plataforma de Seguridad del Instituto de Información Estadística y Geográfica de Jalisco (IIEG),
#  por lo tanto la información es de fuente pública debido a que el Gobierno de Jalisco
#  transparenta la estadística delictiva en la entidad y es presentada de manera interactiva
#  y a través de reportes mensuales. <div>

# %% [markdown]
# ## 2. Descripción de los datos

# %%
# Importar librerias
import pandas as pd
import numpy as np
from datetime import datetime
import re
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('seaborn')
import altair as alt
alt.renderers.enable('default')
import seaborn as sns
import folium

# %%
# Carga del dataset
file = "C:/Users/eduri/OneDrive/Documents/Semestre IV/DPII/datos-2023-03-17.csv"
df = pd.read_csv(file)
df.head(3)
# Out:
#         fecha                 delito           x          y  \
# 0  01/10/2019  Abuso sexual infantil -103.310007  20.688949
# 1  01/10/2019  Abuso sexual infantil -103.505518  20.799957
# 2  01/10/2019  Abuso sexual infantil -103.297919  20.646023
#
#                   colonia    municipio  clave_mun  hora  \
# 0             SANTA MARIA  GUADALAJARA         39  N.D.
# 1  AMPLIACION SANTA LUCIA      ZAPOPAN        120  N.D.
# 2        VICENTE GUERRERO  GUADALAJARA         39  N.D.
#
#                        bien_afectado zona_geografica
# 0  La libertad y la seguridad sexual             AMG
# 1  La libertad y la seguridad sexual             AMG
# 2  La libertad y la seguridad sexual             AMG

# %%
#Observamos las columnas
df.columns
# Out:
# Index(['fecha', 'delito', 'x', 'y', 'colonia', 'municipio', 'clave_mun',
#        'hora', 'bien_afectado', 'zona_geografica'],
#       dtype='object')

# %% [markdown]
# El dataset cuenta con 10 variables

# %%
#Observamos la información de las variables
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 294316 entries, 0 to 294315
# Data columns (total 10 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   fecha            294316 non-null  object
#  1   delito           294316 non-null  object
#  2   x                283367 non-null  float64
#  3   y                283367 non-null  float64
#  4   colonia          294316 non-null  object
#  5   municipio        294316 non-null  object
#  6   clave_mun        294316 non-null  int64
#  7   hora             294316 non-null  object
#  8   bien_afectado    294316 non-null  object
#  9   zona_geografica  294316 non-null  object
# dtypes: float64(2), int64(1), object(7)
# memory usage: 22.5+ MB

# %% [markdown]
# El dataset cuenta con 294,316 registros, es decir, la cantidad de carpetas de investigación por los delitos cometidos en Jalisco.
# Son 7 variables de tipo caracter, 2 flotantes y una variable entera.
# Veamos a que corresponde cada variable:

# %%
# Se observa los valores unicos de cada una de las variables
df.nunique()
# Out:
# fecha               1520
# delito                16
# x                  95260
# y                  98486
# colonia             3077
# municipio            126
# clave_mun            126
# hora                1440
# bien_afectado          4
# zona_geografica        2
# dtype: int64

# %% [markdown]
# ### Información general de los datos

# %%
#fechas
print("- El rango de fechas va desde {0} hasta {1}.".format(df.fecha.unique().min(), df.fecha.unique().max()))
# Out:
# - El rango de fechas va desde 01/01/2019 hasta 31/12/2022.

# %%
# Tipo de delitos
print("- Los distintos tipos de delitos en el dataset son:")
for i in df.delito.unique():
    print("    * "+i)
# Out:
# - Los distintos tipos de delitos en el dataset son:
#     * Abuso sexual infantil
#     * Feminicidio
#     * Homicidio doloso
#     * Lesiones dolosas
#     * Robo a bancos
#     * Robo a carga pesada
#     * Robo a cuentahabientes
#     * Robo a int de vehiculos
#     * Robo a negocio
#     * Robo a persona
#     * Robo a vehiculos particulares
#     * Robo casa habitacion
#     * Robo de autopartes
#     * Robo de motocicleta
#     * Violacion
#     * Violencia familiar

# %%
# Las variables x,y son las longitudes y latitudes de cada uno de los registros
print("-El minimo de longitud de coordenada del dataset es:", min(df.x))
print("-El máximo de longitud de coordenada del dataset es:", max(df.x))
print("-El minimo de latitud de coordenada del dataset es:", min(df.y))
print("-El máximo de latitud de coordenada del dataset es:", max(df.y))
# Out:
# -El minimo de longitud de coordenada del dataset es: -105.5921781
# -El máximo de longitud de coordenada del dataset es: -101.553322
# -El minimo de latitud de coordenada del dataset es: 18.98513745
# -El máximo de latitud de coordenada del dataset es: 22.73658803

# %%
#Colonias 
print("- Nombre de la colonia:")
for i in df.colonia.unique():
    print("    * "+i)
# Out:
# - Nombre de la colonia:
#     * SANTA MARIA
#     * AMPLIACION SANTA LUCIA
#     * VICENTE GUERRERO
#     * MORELOS
#     * LA PENAL
#     * SANTA MARGARITA
#     * LOMAS DEL CUATRO
#     * PARAISOS DEL COLLI
#     * CIRCUNVALACION OBLATOS
#     * LA AURORA
#     * COYULA
#     * BALCONES DEL ROSARIO
#     * SAN MIGUEL CUYUTLAN
#     * SAN JOAQUIN
#     * CONSTANCIO HDEZ ALVIRDE
#     * CHAPALITA SUR
#     * JARDINES DEL VALLE
#     * EL CAPULIN
#     * MIRAMAR
#     * ALTAMIRA
#     * COLINAS DEL REY
#     * SANTA CECILIA
#     * VALLE REAL
#     * ROMITA
#     * JARDINES DE SAN IGNACIO
#     * EL VADO
#     * BALCONES DE SANTA MARIA
#     * LAZARO CARDENAS
#     * LADRON DE GUEVARA
#     * CANTEROS
#     * LAS HUERTAS
#     * NO DISPONIBLE
#     * LA GIGANTERA
#     * BALCONES DE OBLATOS
#     * SANTA CRUZ DE LAS HUERTAS
#     * HACIENDA DEL VALLE
#     * JARDINES DE LA PAZ
#     * EMILIANO ZAPATA
#     * SANTA ELENA DE LA CRUZ
#     * LA CALERA
#     * LAS BOVEDAS
#     * CENTRO
#     * TETLAN
#     * VALLE DE LOS MOLINOS
#     * JARDINES DE NUEVO MEXICO
#     * INDIGENA DE MEZQUITAN
#     * AGUA BLANCA POBLADO
#     * LOMAS DE POLANCO
#     * LOPEZ PORTILLO
#     * HACIENDA REAL
#     * ALDAMA TETLAN
#     * LOMAS DEL MIRADOR
#     * HELIODORO HERNANDEZ LOZA
#     * BLANCO Y CUELLAR
#     * MIRADOR ESCONDIDO
#     * EL BATAN
#     * PARQUE REAL
#     * COLINAS DE LOS ROBLES
#     * HACIENDA SANTA FE
#     * LOMAS DE SAN AGUSTIN
#     * BASILIO BADILLO
#     * CONSTITUCION
#     * VILLASEÑOR (SANTA TERESITA)
#     * LA CASITA
#     * INDEPENDENCIA ORIENTE
#     * ATLAS
#     * VILLA DE GUADALUPE
#     * LARIOS
#     * LAS PEÑITAS
#     * GUAYABITOS
#     * ALAMEDAS DE ZALATITAN
#     * CHIHUAHUA
#     * BALCONES DE LA CANTERA
#     * INSURGENTES
#     * ANALCO
#     * EL MORITO
#     * RANCHO NUEVO
#     * MISION CAPISTRANO
#     * ECHEVERRIA
#     * OSORIO COMUNAL
#     * LOS CANTAROS
#     * DE SAN MARTIN
#     * CENTRO BARRANQUITAS
#     * JUAN DE LA BARRERA
#     * ARCOS DE ZAPOPAN
#     * FELIPE ANGELES
#     * NUEVA GALICIA
#     * LOMAS DE LA PRIMAVERA
#     * LA LADRILLERA
#     * EL COLLI URBANO
#     * TUXPAN
#     * LA RUA
#     * CANTARRANAS
#     * PASEO DE LOS AGAVES
#     * PUENTE GRANDE
#     * SANTA CRUZ DEL VALLE
#     * JARDINES DEL EDEN
#     * BUENOS AIRES
#     * FOVISSSTE MIRAVALLE
#     * COLINAS DE HUENTITAN
#     * JALISCO II SECC
#     * LA JOYA
#     * EL JAGUEY
#     * LA TUZANIA
#     * ZALATITAN CENTRO
#     * LA NOGALERA
#     * PUERTA REAL
#     * LA GRANJA
#     * DEL FRESNO
#     * VALLE DE LOS GIRASOLES
#     * LOS PUESTOS
#     * EL CARMEN
#     * PALMA REAL
#     * LOMA DORADA DELEGACION D
#     * SEATTLE
#     * LOMAS DEL CENTINELA
#     * JARDINES DE SANTA ANA
#     * HUERTAS DE SAN GASPAR
#     * SANTA CECILIA (COLONIA MORELOS)
#     * ARENALES TAPATIOS
#     * RIO BLANCO
#     * JOCOTAN
#     * RESIDENCIAL DEL VALLE
#     * JUANACATLAN
#     * TOLUQUILLA
#     * BALCONES DEL CUATRO
#     * CONDOMINIO CAMPO DE GOLF SANTA ANITA
#     * LOMA BONITA EJIDAL
#     * LOMAS DEL SUR
#     * MIRADOR
#     * TULIPANES
#     * BOSQUES DE TONALA
#     * LOS SANTIBAÑEZ
#     * VALLE DE TEJEDA
#     * JARDINES DE VERANO
#     * JARDINES DE LOS HISTORIADORES
#     * EL BETHEL
#     * SAN JUAN DE OCOTAN
#     * REAL DEL SOL
#     * PROGRESO
#     * MIRAFLORES
#     * SAN JOSE EJIDAL
#     * PARQUES DE SAN PEDRO
#     * SAN JOSE DEL CASTILLO
#     * LOS PORTALES
#     * JALISCO IV SECC
#     * HACIENDA DEL SOL
#     * ZAPOTE DEL VALLE
#     * JARDINES DE LA CALERA
#     * MODERNA
#     * LOS POCITOS
#     * CHULAVISTA E1
#     * PASEOS DEL PRADO
#     * SAN ANTONIO
#     * BENITO JUAREZ
#     * SAN PEDRITO
#     * SAN FRANCISCO
#     * REFORMA
#     * MIRAVALLE
#     * SAN SEBASTIAN EL GRANDE
#     * EL ZALATE
#     * EL HUMEDO DE NEXTIPAC
#     * LOMAS DE TABACHINES
#     * EL RASTRO
#     * MESA DE LOS OCOTES
#     * EL VERGEL
#     * TONALA CENTRO
#     * LA ARENA
#     * AGRICOLA
#     * ZONA CENTRO
#     * URBIQUINTA MONTECARLO
#     * SANTA ROSA DEL VALLE
#     * LA CORONILLA
#     * SANTA CRUZ DE LAS FLORES
#     * AMERICANA
#     * VILLAS DE ORIENTE I
#     * EL SAUZ
#     * BELLAVISTA
#     * LA DURAZNERA
#     * EL CERRITO
#     * JARDINES DEL VERGEL
#     * INDIGENA
#     * EL RETIRO
#     * DIVISION DEL NORTE
#     * CIRCUNVALACION BELISARIO
#     * CIUDAD AZTLAN
#     * DR VALENTIN GOMEZ FARIAS
#     * JARDINES DEL BOSQUE
#     * SAN JUAN BOSCO
#     * AGUA FRIA
#     * SAN CLEMENTE
#     * LAS JUNTAS
#     * SAN JUAN
#     * JARDINES DE SANTA ISABEL
#     * HACIENDA LA NORIA
#     * BOSQUES DE LA VICTORIA
#     * ARTESANOS
#     * JARDINES DE SAN MARTIN
#     * BEATRIZ HERNANDEZ
#     * VILLA LUNA
#     * LOMAS INDEPENDENCIA
#     * EL ZAPOTE
#     * VALLE DORADO 2DA SECCION INN
#     * PRADOS DE SANTA LUCIA
#     * EL FORTIN
#     * SAN VICENTE
#     * MISION EL CAMPANARIO
#     * LOMAS DEL COLLI
#     * JAUJA
#     * CERRO DEL CUATRO
#     * PACIFICO
#     * SANTA ROSA
#     * LOMAS DEL GALLO
#     * COLINAS DE SAN CARLOS
#     * LAS ARBOLEDAS
#     * LOMAS DEL REFUGIO
#     * POPULAR HORNOS
#     * JARDINES DE LA CRUZ ORIENTE
#     * AARON JOAQUIN
#     * LOMAS DEL PARAISO I
#     * SAN MARTIN
#     * LOMA DORADA DELEGACION B
#     * CHAPULTEPEC COUNTRY
#     * POLANCO
#     * 8 DE JULIO
#     * SAN AGUSTIN
#     * JARDINES TAPATIOS
#     * LINDAVISTA
#     * JARDINES DE LOS BELENES
#     * VALLES DE NUEVO MEXICO
#     * PARQUES DEL BOSQUE
#     * EL CAMPESINO
#     * RITZ AUTOCINEMA
#     * ARTESANOS (SAGRADA FAMILIA Y/O JESUS)
#     * HACIENDA LOS FRESNOS
#     * OLIMPICA
#     * LA PERLA
#     * DESPERTARES
#     * PRADOS COYULA
#     * LA ESPERANZA (LA FEDERACHA)
#     * LA PATRIA UNIVERSIDAD
#     * SANTA PAULA
#     * SAN MARCOS
#     * HACIENDA LAS PALOMAS
#     * LOMAS DE SAN EUGENIO
#     * FRACCIONAMIENTO RESIDENCIAL SAN JOSE
#     * EL PALOMAR
#     * VALLARTA
#     * INDEPENDENCIA
#     * EL REFUGIO
#     * 1 DE MAYO
#     * HUENTITAN EL BAJO
#     * JARDINES DE SANTA MARIA
#     * VILLAS LOS CANTAROS
#     * LOMA LINDA
#     * EL CASTILLO
#     * LOMAS DE TLAQUEPAQUE
#     * SANTA MARIA TEQUEPEXPAN
#     * FRANCISCO I MADERO 2a SECCION
#     * 20 DE NOVIEMBRE
#     * EL ORGANO
#     * ALAMO ORIENTE
#     * NUEVA ESPAÑA
#     * GEO VILLAS LOS OLIVOS
#     * LOMAS DE INDEPENDENCIA
#     * FERROCARRIL
#     * LAS LIEBRES
#     * BARRAGAN HERNANDEZ
#     * LOS AMIALES
#     * DEL SUR
#     * SAN MARTIN DE LAS FLORES DE ABAJO
#     * SANTA ANA TEPETITLAN
#     * LA PAZ
#     * ZOQUIPAN
#     * LA VENTA DEL ASTILLERO
#     * LAS AGUJAS
#     * CUAUHTEMOC
#     * GUADALAJARA ORIENTE
#     * LOMAS DEL PARAISO II
#     * BALCONES DEL SOL
#     * SAN JUAN DE DIOS II
#     * SAN SEBASTIANITO
#     * VALLARTA LA PATRIA
#     * CUMBRES
#     * MEXICALTZINGO
#     * JALISCO III SECC
#     * PUERTA DE HIERRO
#     * SAN ANDRES
#     * CAMINO REAL
#     * EL MANTE
#     * SAN MIGUEL DE HUENTITAN
#     * SANTA TERE
#     * COLINAS DE TABACHINES
#     * LA NORIA
#     * INFONAVIT ESTADIO
#     * VILLAS TORREMOLINOS
#     * LA MARTINICA
#     * LOMAS DE RIO VERDE
#     * JARDINES DE SAN FRANCISCO
#     * MISION SAN FRANCISCO II
#     * LAGOS DE ORIENTE
#     * VILLAS DE SAN AGUSTIN
#     * HACIENDA DE LOS EUCALIPTOS
#     * CIUDAD DEL SOL
#     * LOMAS DE GUEVARA
#     * LOMA DORADA
#     * JALISCO I SECC
#     * LOMA BONITA
#     * LOMAS DEL LAUREL I
#     * MISION DE LOS VIÑEDOS
#     * BALCONES DEL ROSARITO
#     * SAN GASPAR
#     * LOS ARRAYANES
#     * INFONAVIT TONALA (RIO NILO)
#     * COLLI CTM
#     * LOMAS DE SAN MIGUEL
#     * AGUA BLANCA INDUSTRIAL
#     * MIRADOR DEL SOL
#     * GUADALUPE SUR
#     * MONRAZ
#     * LOMAS UNIVERSIDAD
#     * MESA COLORADA ORIENTE
#     * LA COFRADIA
#     * VILLAS DE SAN GILBERTO
#     * LOMA REAL
#     * SANTA LUCIA
#     * UNIDAD JOSE LUIS LOPEZ PORTILLO
#     * MARIANO OTERO
#     * TATEPOSCO (SAN JOSE DE TATEPOSCO)
#     * SANTA ELENA ESTADIO
#     * ARBOLADA BOSQUES DE SANTA ANITA
#     * LA MAGDALENA
#     * AGUA ESCONDIDA
#     * LOMAS DEL CAMICHIN
#     * VILLA FONTANA AQUA
#     * VICTORIA
#     * ALBORADA
#     * URBIVILLA DEL RIO
#     * BELISARIO DOMINGUEZ
#     * ALAMEDA
#     * LA PUNTA
#     * SAN CARLOS
#     * VILLAS ANDALUCIA
#     * LA FLORIDA
#     * UNION DEL CUATRO
#     * VILLAS DE LA LOMA
#     * EL CAMPANARIO
#     * 5 DE MAYO
#     * MIGUEL HIDALGO
#     * LIBERTAD
#     * ARBOLEDAS DE SAN GASPAR
#     * RUBEN JARAMILLO
#     * SANTA CATALINA
#     * BARRIOS UNIDOS INTERCOLONIAS
#     * LOMAS DEL TAPATIO
#     * EL BRISEÑO
#     * EL MIRADOR
#     * LOPEZ COTILLA
#     * FRANCISCO VILLA
#     * HERNANDEZ ROMO
#     * ARROYO HONDO
#     * SORRENTO
#     * LAS FLORES
#     * ATEMAJAC DEL VALLE
#     * VILLA GUERRERO
#     * COLINAS DE ATEMAJAC
#     * TETLAN II
#     * LA PROVIDENCIA
#     * AZALEAS
#     * CHAPALITA INN
#     * JARDINES DE LA CRUZ
#     * 12 DE DICIEMBRE
#     * LOMAS DEL BATAN
#     * EL ABREVADERO
#     * VILLAS TERRANOVA
#     * OBLATOS
#     * SANTA MARGARITA RESIDENCIAL
#     * LA CALMA
#     * EL TIGRE
#     * LA SOLEDAD
#     * VILLAS DEL CARMEN
#     * SAN JOSE RIO VERDE
#     * TATEPOSCO
#     * RANCHO DE LA CRUZ
#     * JARDINES UNIVERSIDAD
#     * EL VIGIA
#     * EL DERRAMADERO
#     * RESIDENCIAL DE LA BARRANCA
#     * SAN ISIDRO OBLATOS
#     * LOS CAJETES
#     * SANTA ANITA
#     * LOMAS DE ZAPOPAN
#     * SANTA MONICA DE LOS CHORRITOS
#     * JARDINES DEL SAUZ
#     * TONALTECAS I
#     * LOS MANGUITOS
#     * LOMA BONITA I
#     * COMOLEA
#     * LA GUADALUPANA
#     * LOS CAMICHINES I
#     * LOMA DEL ZALATE (AHUATAN)
#     * ALAMO INDUSTRIAL
#     * OBRERA
#     * DR ATL
#     * SAN EUGENIO
#     * SAN ISIDRO EJIDAL
#     * EL EJIDO COPALITA
#     * SAN JUAN DE DIOS
#     * LEYES DE REFORMA
#     * MIRADOR ORIENTE
#     * CANTERA MORADA
#     * PARQUES DE TESISTAN
#     * CIUDAD GRANJA
#     * SAN BERNARDO
#     * SAN MARTIN DE LAS FLORES DE ARRIBA
#     * PRADO ARBOLEDAS
#     * MEZQUITAN COUNTRY
#     * ARBOLEDAS DE SAN MARTIN
#     * ARVENTO
#     * LAS TORRES
#     * VILLAS FONTANA
#     * VALLARTA PONIENTE
#     * MISION DE LA CANTERA
#     * PLAN DE ORIENTE
#     * SAN RAFAEL
#     * CANTERA COLORADA
#     * TETLAN RIO VERDE
#     * PUESTA DEL SOL
#     * FOVISSSTE (ESTATUTO JURIDICO)
#     * LA MESA COLORADA PONIENTE
#     * POTRERO SAN JOSE
#     * MISION SAN FRANCISCO III
#     * VISTA HERMOSA
#     * COLINAS DESARROLLO
#     * LA ALAMEDA
#     * ARCOS DE ZALATITAN
#     * LA ESTANCIA
#     * ALTAGRACIA
#     * COLINAS DEL ROBLE
#     * VALLE DE LA PRIMAVERA
#     * SILOS
#     * JARDINES DEL AUDITORIO
#     * COLON
#     * JARDINES DE LOS ARCOS
#     * DEL BOSQUE
#     * LOMAS DEL VERGEL
#     * LAS AGUILAS
#     * EL PLAN
#     * EL TAPATIO
#     * SANTA ISABEL II
#     * SOLIDARIDAD
#     * CAMICHINES
#     * COLEGIO DEL AIRE
#     * HACIENDAS LA CANDELARIA
#     * REVOLUCION
#     * EL SINAI
#     * LA LOMA
#     * EL ALAMO
#     * COUNTRY CLUB
#     * JUANACATLAN CENTRO
#     * BALCONES DE SANTA ANITA
#     * PUERTA SOL
#     * HERMOSA PROVINCIA
#     * BOSQUES DEL CENTINELA
#     * INFONAVIT EL GARABATO
#     * JARDINES DEL CAMICHIN 125
#     * LA MORA
#     * LOS ROBLES
#     * NUEVA SANTA MARIA
#     * SAN JOSE DE LAS FLORES
#     * REAL DEL VALLE
#     * REAL DEL PARQUE
#     * LOS COLORINES
#     * LA HUERTA
#     * DEL HUERTO
#     * DE GUADALUPE
#     * VALLE DE LOS OLIVOS
#     * EL REFUGIO DEL VALLE
#     * PALMIRA
#     * LOMAS DE OBLATOS
#     * EL ROSARIO
#     * TESISTAN
#     * MONUMENTAL
#     * CAJITITLAN
#     * ATLAS COLOMOS
#     * BANUS
#     * VALLARTA NORTE
#     * FRANCISCO SILVA ROMERO
#     * LOPEZ MATEOS
#     * LOMA DORADA DELEGACION C
#     * ROYAL COUNTRY
#     * LOMAS DE LA VICTORIA
#     * BALCONES DE TLAJOMULCO
#     * SAN PABLO
#     * MONTEVERDE III
#     * NUEVO VERGEL
#     * TEPEYAC
#     * COL HEROES DE CHAPULTEPEC (EL ROMERE?O INFONAVIT)
#     * SAN ELIAS
#     * PARQUES DE ZAPOPAN
#     * VILLAS BELENES
#     * ARANDAS
#     * CIELITO LINDO
#     * VILLAS DE SANTA LUCIA
#     * LA ESPERANZA
#     * LA HORTALIZA
#     * COLORADO
#     * VILLAS DE GUADALUPE
#     * LOMAS DEL CARMEN
#     * NEXTIPAC
#     * ZAPOTITLAN DE HIDALGO
#     * ARBOLEDAS
#     * ARROYO LAS FLORES
#     * PARQUES DEL CASTILLO
#     * POTRERO NUEVO
#     * TINAJITAS
#     * GEOVILLAS LA ARBOLADA
#     * PARQUES DE LA VICTORIA
#     * JARDINES DEL ROSARIO
#     * NUEVA PRIMAVERA
#     * VALLE DE LOS SABINOS I
#     * NIÑOS HEROES
#     * LOS MESEROS
#     * SANTA MARIA DEL PUEBLITO
#     * LA ALCANTARILLA
#     * ZONA INDUSTRIAL
#     * LUIS ALONSO
#     * VALLE DORADO
#     * LOMAS DEL PARAISO III
#     * ARROYO DE ENMEDIO
#     * BRISAS DEL NILO
#     * LOMA DORADA (EJIDAL)
#     * PEDRO MORENO
#     * CRISTO REY
#     * SUTAJ
#     * REY XOLOTL
#     * LA TIJERA
#     * LAGOS DEL COUNTRY
#     * AGAVEROS
#     * OLAS ALTAS
#     * SAGRADA FAMILIA
#     * EL CERRO DE LA CRUZ
#     * LA ERMITA
#     * PALOS ALTOS
#     * PANTEON
#     * LA CANTERA
#     * LAS AGUILILLAS
#     * EL PEDREGAL
#     * AGUA BLANCA
#     * CAPILLA DE GUADALUPE
#     * SANTA MARIA DEL VALLE
#     * JARDINES SANTA MARIA
#     * TEPONAHUASCO
#     * RIBERAS DE SANTA BARBARA I
#     * BUENAVISTA
#     * EL SANTUARIO
#     * VALLE DE LAS ARBOLEDAS
#     * LOS SABINOS
#     * LOS DOLORES
#     * NUEVO BELLAVISTA
#     * CONASUPO
#     * LAS COLONIAS
#     * LAS HADAS
#     * CBTA
#     * SAN JOSE DE GRACIA
#     * MEZCALA
#     * LA LAGUNA
#     * CRISTEROS
#     * SAN JOSE
#     * LA ADELITA
#     * SAN MIGUEL
#     * LOMAS VERDES
#     * EL RANCHITO
#     * LA ESMERALDA
#     * LARIZ
#     * BUGAMBILIAS
#     * COLINAS DE SAN JOSE
#     * LA CUESTA (CUESTA DE MEDINA)
#     * PASEOS DE LA MONTAÑA
#     * ALCALDES
#     * EL PASO PEDREGOSO
#     * LA TROJE
#     * POTRERO DE FRAY RAMON
#     * EL PUESTO
#     * PUEBLO DE MOYA
#     * VILLAS DE SAN JAVIER
#     * BAJIO DE SAN JOSE
#     * RIVIERA
#     * CAÑADA DE RICOS
#     * SANTO TOMAS
#     * SAN JUAN DE LOS LAGOS
#     * CLUB DE LEONES
#     * EL TEPETATE
#     * EL TOREO
#     * SANTA TERESA
#     * LOS CHIRLITOS
#     * DE LA ARBOLEDA
#     * EL MIRTO
#     * EJIDAL
#     * BETANIA
#     * LA CONCEPCION
#     * LA HACIENDA
#     * EL NUEVO FUERTE
#     * TLACHICHILCO DEL CARMEN
#     * RIVERAS DE ZULA
#     * SAN IGNACIO (LA CAÑADA)
#     * SAN JOSE DE LAS MORAS
#     * MASCOTA
#     * CANTERIA
#     * LA PRIMAVERA
#     * SAN PEDRO ITZICAN
#     * TEODOSIO R GUEVARA
#     * SAN FRANCISCO DE ASIS (FCO JAVIER MINA)
#     * LOS OLIVOS
#     * HUASCATO
#     * SAN JUAN COSALA
#     * PLAZA DE TOROS
#     * ACATLAN DE JUAREZ
#     * LOS GIGANTES
#     * INFONAVIT EL CASTILLO
#     * CIMA SERENA
#     * LA PURISIMA
#     * CAMPO BELLO
#     * LA ESTANCIA (CARTOLANDIA)
#     * VALLE DE LOS OLIVOS II
#     * BONITO JALISCO
#     * TEPEHUA
#     * EL TAJO
#     * ATOTONILCO EL BAJO
#     * POTRERILLOS
#     * ANIMA SOLA
#     * CITALA
#     * EL TERRERO
#     * CHAPALA CENTRO
#     * ARENA
#     * CARDENAS DEL RIO
#     * ATOTONILQUILLO
#     * EL PANTEON
#     * JALISCO
#     * LOMAS DEL SALTO
#     * VALLE DE LOS SABINOS IV
#     * SAN CRISTOBAL ZAPOTITLAN
#     * BAJA CALIFORNIA
#     * CIMEG
#     * GALAXIA BONITO JALISCO
#     * VALLE DE LOS SABINOS III
#     * CONSTITUYENTES
#     * LAS HACIENDAS
#     * ZACOALCO DE TORRES CENTRO
#     * PINTORES
#     * LA HIGUERA
#     * EL RINCON
#     * CIUDAD GUZMAN CENTRO
#     * GENERAL ANDRES FIGUEROA
#     * TAMAZULA DE GORDIANO
#     * TULILLO
#     * SAN SEBASTIAN DEL SUR
#     * LA TALPITA
#     * NUEVO DESARROLLO
#     * SAN JOSE DE LA TINAJA
#     * ZAPOTITLAN DE VADILLO
#     * DE LOS CASTILLO
#     * ATENQUIQUE
#     * SOYATLAN DE AFUERA
#     * JARDINES DEL SOL
#     * 27 DE SEPTIEMBRE
#     * LA TEJA
#     * MARCELINO GARCIA BARRAGAN (AZUCARERA)
#     * ORIENTE SEGUNDA SECCION
#     * LA LOMA (UNIDAD DEPORTIVA)
#     * CHARCO DE LOS ADOBES
#     * EL TECOLOTE
#     * EJUTLA
#     * ARQUITOS
#     * AZTECA
#     * TAMAZULITA
#     * COPALA
#     * LAS MOJONERAS
#     * LOMAS DEL COAPINOLE
#     * COAPINOLE
#     * MORELOS Y PAVON
#     * LA PEDRERA
#     * VILLA LAS FLORES
#     * EL PALMAR DE IXTAPA
#     * EL TORO
#     * BOBADILLA
#     * INFONAVIT CTM (UNIDAD HABITACIONAL HELIODORO HERNANDEZ LOZA)
#     * LA FLORESTA
#     * CRISTOBAL COLON
#     * EL CALOSO
#     * LAS PEÑAS
#     * ZONA HOTELERA NORTE
#     * CENTRO PITILLAL
#     * LOMAS DE SAN NICOLAS
#     * CERRO
#     * EL PALMAR DEL PROGRESO
#     * VOLCANES DE VALLARTA
#     * PARQUES UNIVERSIDAD (SENDERO DE LUNA)
#     * CHULA VISTA
#     * VIDA VALLARTA
#     * DIAZ ORDAZ
#     * LOMAS DE ENMEDIO
#     * EL CALVARIO
#     * BARRIO SANTA MARIA
#     * CAMPO VERDE
#     * EDUCACION
#     * VALENTIN GOMEZ FARIAS
#     * JOYAS DEL PEDREGAL
#     * CENTRO IXTAPA
#     * CRUZ DE LORETO
#     * LA VENA
#     * CAMPO ACOSTA
#     * LAS GLORIAS
#     * EL PROGRESO
#     * VERSALLES
#     * BRISAS DEL PACIFICO
#     * 5 DE DICIEMBRE
#     * COSTA DORADA
#     * PASEOS DEL HIPODROMO
#     * PALMARES UNIVERSIDAD
#     * SAN ESTEBAN
#     * YERBABUENA
#     * LISBOA RESIDENCIAL
#     * RAMBLASES
#     * LA DESEMBOCADA
#     * JARDINES
#     * IDIPE (INFONAVIT)
#     * JOSE MARIA PINO SUAREZ
#     * LOS TAMARINDOS
#     * LA PLAYITA
#     * CENTRO DE SALUD
#     * CONCHAS CHINAS
#     * LOS MEZQUITES
#     * SOYATLAN DEL ORO
#     * LA ASCENCION
#     * LA CRUZ
#     * LA VEGA
#     * EL CHARCO VERDE
#     * LAS NORIAS
#     * EL VENADO
#     * LOS RUISEÑORES
#     * SAN PEDRO
#     * GAMBOA
#     * CHAPARRAL
#     * OBRERA 2
#     * CUXPALA
#     * NUEVA XOCHILTEPEC
#     * REAL
#     * SAN JUAN DE LOS ARCOS
#     * LA CIMA
#     * LOS BARRANCONES
#     * LOS FRESNOS
#     * SANTA CRUZ DE BARCENA
#     * LOMAS DEL PARAISO
#     * DEL CENTRO
#     * DE TAPIAS
#     * LAS GOLONDRINAS
#     * SOYATITLAN
#     * LOMAS DE LA CRUZ
#     * LAS CRUCES
#     * SAN MATEO
#     * JALUCO
#     * CORRAL DE PIEDRA DE NUEVO
#     * PURIFICACION
#     * LA NARANJERA
#     * BARRA DE NAVIDAD
#     * VILLA OBREGON
#     * TREJOS
#     * CAJA POPULAR
#     * FOVISSSTE DOCTORES
#     * JUAN LOZA
#     * HACIENDAS DEL PALOMINO
#     * SAN SEBASTIAN DEL ALAMO
#     * DEL CARMEN
#     * RITA PEREZ DE MORENO
#     * MATANZAS
#     * SAN ANTONIO DE RIVAS
#     * LA PUERTA DEL GUAMUCHIL
#     * SAN GABRIEL
#     * EL CARACOL
#     * LA PRIMAVERA RESIDENCIAL
#     * FLORIDA
#     * 6 DE NOVIEMBRE
#     * EL PORVENIR
#     * VILLA GARCIA MARQUEZ
#     * SAN NICOLAS
#     * RINCONADA
#     * LAZARO CARDENAS Y UNIDAD
#     * LA AZUCENA
#     * AJIJIC
#     * LAS CANOITAS
#     * LOURDES
#     * LA CASCADA
#     * HUEJOTITAN
#     * SANTIAGUITO
#     * PIHUAMO
#     * EL FRESNITO (LA MESA)
#     * LAS CEBOLLAS
#     * GUADALUPE
#     * USMAJAC
#     * HUESCALAPA
#     * CRUZ BLANCA
#     * EL JAZMIN
#     * CRUZ ROJA
#     * SAN JOSE DEL TULE
#     * POCITO SANTO
#     * DEL ALAMO
#     * JARDINES DE AUTLAN 2
#     * LA QUINTA
#     * CERRO COLORADO
#     * LOS SAUCES
#     * DEL MAR
#     * LOMAS DEL PEDREGAL
#     * SANTO DOMINGO
#     * EL MAGISTERIO
#     * GUADALUPE VICTORIA
#     * VILLA DEL ROSARIO
#     * MIGUEL DE LA MADRID
#     * LA ESTACION
#     * SAN CRISTOBAL DE LA BARRANCA CENTRO
#     * AHUALULCO CENTRO
#     * 12 DE OCTUBRE
#     * DE LA PIEDRA CHINA
#     * LA COFRADIA (LA COFRADIA DE LA LUZ)
#     * CUZALAPA
#     * CARLOS RIVERA ACEVES
#     * COMERCIAL ABASTOS
#     * EL CHIRIMOYO
#     * LOMAS DE TEJEDA
#     * INFONAVIT LA SOLEDAD
#     * VALLE DE LOS EMPERADORES
#     * LOMAS DEL VALLE
#     * SAN MARTIN DE ZULA
#     * EL MUELLE (EL MUEY)
#     * RIVIERA SANTO DOMINGO (AMPLIACION SANTO DOMINGO)
#     * CAMPESTRE LAS PALMAS
#     * TANANA
#     * LA MEZCALERA
#     * LA MANZANILLA
#     * LA CAPACHA
#     * MIRADOR DEL VALLE
#     * LAS POMAS
#     * JARDIN REAL
#     * PINAR DE LAS PALOMAS
#     * LA LAJA
#     * PAISAJES DEL TESORO
#     * DR. VALENTIN GOMEZ FARIAS
#     * ALVARO OBREGON
#     * LA LLAVE
#     * LINDAVISTA COUNTRY
#     * AUDITORIO
#     * VALLARTA SAN JORGE
#     * HACIENDA SANTA CRUZ
#     * CABAÑITAS
#     * LOS ANGELES
#     * LAS CONCHAS
#     * SAN JUAN EVANGELISTA
#     * OJO DE AGUA
#     * JARDINES DEL SUR
#     * RICARDO FLORES MAGON
#     * LOMAS DEL TESORO
#     * HIDALGO
#     * LOMAS DE SANTA MARIA
#     * HORMIGUERO
#     * PASEO PUENTE VIEJO
#     * VILLAS DEL TAPATIO
#     * PUNTO SUR
#     * RANCHO ALEGRE
#     * FRANCISCO I MADERO
#     * LAS PALMAS
#     * PACHAGUILLO
#     * VALLE DE LA MISERICORDIA
#     * RANCHO SAN GABRIEL
#     * LA CONCHA
#     * LOMAS DE SAN GONZALO
#     * POLANQUITO PONIENTE
#     * CHAPALITA ORIENTE
#     * LOS CHINOS
#     * REAL DE SAN SEBASTIAN
#     * PORTILLO LOPEZ (SALVADOR PORTILLO LOPEZ)
#     * VALLE BALCONES DE SANTA MARIA
#     * PASEOS DE SANTIAGO
#     * DEL PERIODISTA
#     * DE LAS FLORES
#     * PASEOS DEL LAGO
#     * GUADALUPE EJIDAL
#     * EDUCADORES JALISCIENSES
#     * PINAR DE LA CALMA
#     * EL DEAN
#     * LA GLORIA DEL COLLI
#     * QUINTAS DEL VALLE
#     * SAN ISIDR0 ( POTRERO DE SAN ISIDRO)
#     * COLONIAL TLAQUEPAQUE
#     * LA ASUNCION
#     * LOMAS DEL PARADERO
#     * REVOLUCIONARIA
#     * HIGUERILLAS
#     * HACIENDA DE TLAQUEPAQUE
#     * TABACHINES
#     * LOMAS DEL BOSQUE
#     * HACIENDAS DE SAN JOSE
#     * PASEOS DEL VALLE
#     * LA PIEDRERA
#     * LAS GAMBOAS
#     * PONIENTE
#     * COLINAS DE LA NORMAL
#     * RINCONADAS DEL BOSQUE
#     * PRADOS DE LA CAÑADA
#     * NUEVA CENTRAL CAMIONERA
#     * ESTRADA
#     * VILLAS DE LA HACIENDA
#     * COFRADIA
#     * QUINTAS DEL FEDERALISMO
#     * LA MEZQUITERA
#     * FRANCISCO SARABIA
#     * LOMA DORADA DELEGACION A
#     * HACIENDA DE VIDRIO
#     * PARQUES DE TLAQUEPAQUE
#     * LA SILLITA
#     * EL REAL
#     * VILLAS MIRADOR
#     * VILLA UNIVERSITARIA
#     * VISTAS DEL CUATRO
#     * SANTA ELENA ALCALDE
#     * LAS VILLAS
#     * MISION LA VALENCIANA
#     * CRUCERO CENTRAL
#     * DON BOSCO VALLARTA
#     * JOSE CLEMENTE OROZCO
#     * 18 DE MARZO
#     * LOS MOLINOS
#     * COLINAS DEL RIO
#     * EL TIZATE
#     * HACIENDAS DE LA REYNA
#     * LOMAS DEL COUNTRY
#     * EL VERDE ( PLANETARIO)
#     * ARCOS VALLARTA
#     * PRADERAS DE SAN ANTONIO
#     * LA FLORESTA DEL COLLI
#     * VILLALTA
#     * NUEVO ISRAEL
#     * MAGAÑA
#     * COPALITA
#     * POTRERO DEL CANDADO
#     * HACIENDA COLIMILLAS
#     * HUENTITAN EL ALTO
#     * LA FORTUNA
#     * JARDINES DE SAN JOSE
#     * LOMAS DEL MANANTIAL
#     * SANTA EDUWIGES
#     * 4 ESTACIONES
#     * BALCONES DE LA CALERA
#     * REAL DEL CARMEN
#     * PROVIDENCIA
#     * ATLAS CHAPALITA
#     * SAN ISIDRO
#     * LOMAS DE LA SOLEDAD
#     * JARDINES DEL COUNTRY
#     * PARQUES DE STA CRUZ DEL VALLE
#     * LA COLADERA
#     * TEMPISQUE
#     * MIRADOR DEL BOSQUE
#     * ESENCIA
#     * EL PARAISO
#     * VILLA HERMOSA
#     * LA PERIQUERA
#     * AGUSTIN YAÑEZ (LA FLORIDA)
#     * BARRIO NUEVO
#     * PUERTA DEL TULE
#     * VIVEROS DEL REAL
#     * SAN JOSE DEL TAJO
#     * BOSQUE CEDROS SANTA ANITA
#     * TERRALTA
#     * REAL DE VALDEPEÑAS
#     * HACIENDAS TONALA
#     * SAN LUCAS EVANGELISTA
#     * CIUDAD BUGAMBILIAS
#     * LA MICAILITA
#     * IXCATAN
#     * CAMICHINES VALLARTA
#     * EL MANANTIAL
#     * LOMA EL PEDREGAL
#     * PROVIDENCIA 4a SECCION
#     * EL BAJIO
#     * CRUCERO DE LA MESA
#     * VILLAS DE SAN MARTIN
#     * MIRADOR DEL TESORO
#     * ARCOS DE GUADALUPE
#     * ALFAREROS
#     * PARQUES COLON
#     * CORRECCIONAL
#     * LA CALERILLA
#     * COLINA DE LOS BELENES
#     * SOARE ACANTIA I
#     * EL BOSQUE
#     * MEXICO
#     * QUINTERO
#     * MIRADOR ALAMO INDUSTRIAL
#     * SOLARES
#     * VALLE DE LOS ENCINOS
#     * CHAPALITA
#     * PASEOS DEL SOL
#     * JARDINES VALLARTA
#     * RESIDENCIAL CHAPALITA
#     * MEZQUITAN
#     * QUINTA VELARDE
#     * CUEXCOMATITLAN
#     * SAN MIGUEL DE MEZQUITAN
#     * TRES PINOS
#     * HACIENDA CASA FUERTE
#     * MATATLAN
#     * JARDINES DE TONALA
#     * JARDINES DEL ZAPOTE
#     * SANTA ANITA CAMINO REAL
#     * ALCALDE BARRANQUITAS
#     * RESIDENCIAS  DEL PRADO
#     * SANTA ISABEL
#     * HABITACIONAL TEJEDA
#     * FRENTE POPULAR TONALTECA
#     * SAN JOSE DE LA PAZ
#     * SAN ANTONIO DE LOS VAZQUEZ
#     * LA CANTERIA
#     * PASO NUEVO
#     * AGUA CALIENTE
#     * MARTIRES CRISTEROS
#     * LA PALMA
#     * EL TEPEYAC
#     * LA CAMPANA
#     * LOMA DE VELOCES
#     * HUERTOS FAMILIARES SAN PEDRO
#     * VILLAS ESMERALDA
#     * MATANCILLAS
#     * ROSA DE CASTILLA
#     * LADERA GRANDE
#     * PLAN DE LOS RODRIGUEZ
#     * SANTA MARIA TRANSPONTINA (SANTA MARIA DE ABAJO)
#     * LAS HUERTITAS
#     * CRUZ DE BUENOS AIRES
#     * GRANADILLAS
#     * LADERA CHICA
#     * EL TECUAN
#     * MARAVILLAS
#     * JOSE MA ESCRIVA DE BALAGUER
#     * JARDINES DE LA CAPILLA
#     * LOS JACALES
#     * LA ORILLA DEL AGUA
#     * PRADOS DE LA ESTACION
#     * GEOVILLAS DE LOS LAGOS
#     * EL CHIPINQUE DE ARRIBA
#     * SAN LUIS (SANTO NIÑO)
#     * LOS ALTOS
#     * COMANJA DE CORONA
#     * EL JOSEFINO
#     * SAN FELIPE
#     * SAN MIGUEL ZAPOTITLAN
#     * NUEVO PROGRESO
#     * JAVIER GARCIA PANIAGUA
#     * COINAN GRANDE
#     * SAN MIGUEL DE LA PAZ
#     * EL GRANJENO
#     * LOMAS DEL AEROPUERTO
#     * LA CAPILLA
#     * MODELO EMILIANO ZAPATA
#     * SAN JOSE DEL QUINCE
#     * LOS MAESTROS
#     * SAN ANTONIO TLAYACAPAN
#     * IXTLAHUACAN DE LOS MEMBRILLOS CENTRO
#     * SANTA CRUZ DE LA SOLEDAD
#     * MINERALES
#     * SAN JUDITAS O GUADALUPANA
#     * LAS CUEVAS 2
#     * LOMA VERDE
#     * AGUA ZARCA 2
#     * SAN NICOLAS DE IBARRA
#     * ERMITA
#     * LOS MANGOS
#     * LAS CARRETAS
#     * LAS REDES
#     * EXHACIENDA VIEJA DEL CASTILLO
#     * EL CHANTE
#     * LA UNIDAD DEPORTIVA
#     * HERMOSILLO
#     * ACATLAN DE JUAREZ CENTRO
#     * PRESA CORONA
#     * LOMAS DEL VERDE EJIDAL
#     * LAS LILAS
#     * SAN LUIS SOYATLAN
#     * PARAISO
#     * EL MOLINO
#     * NAJAYOTE
#     * GUADALUPE DE MONTENEGRO
#     * LOMAS DE SAN JUAN
#     * UNIDAD DEPORTIVA SUR
#     * SANTA CRUZ
#     * FRESNO
#     * EL RODEO
#     * ALTO
#     * LA GARITA
#     * EL TINACO
#     * SANTA ROSALIA
#     * AUTLAN DE NAVARRO
#     * QUILA
#     * SAN PEDRO TOXIN
#     * EL ALAMBRE PONIENTE
#     * VERDE VALLARTA
#     * FLUVIAL VALLARTA RESIDENCIAL
#     * MARINA VALLARTA
#     * DE SAN MIGUEL
#     * PALO VERDE
#     * LA MURALLA
#     * SANTA CRUZ DEL ASTILLERO
#     * LOMAS DE ETZATLAN
#     * NUEVO
#     * LA ESTANZUELA
#     * SAN MARTIN DE LAS CAÑAS
#     * HUACASCO
#     * PABELO
#     * MIGUEL HIDALGO NUEVO
#     * BOSQUES DE LA GLORIA
#     * SAN MIGUEL BUENAVISTA
#     * LOS TUNEROS
#     * PRESIDENTES 2
#     * GUADALUPANO
#     * EL MOSAICO
#     * SAN ISIDRO DE ARRIBA
#     * EMILIANO ZAPATA 2
#     * EL SALITRE
#     * VIRGEN DE GUADALUPE 2
#     * EL VERDE
#     * FIDEL VELAZQUEZ I
#     * JARDINES DE LA EXHACIENDA
#     * JARDINES DEL VERDE
#     * VILLA CORONA CENTRO
#     * JOCOTEPEC CENTRO
#     * COMPOSITORES
#     * LOS MAZOS
#     * CAMPAMENTO FERROCARRILERO
#     * EL COLORADO
#     * LAS DELICIAS
#     * LOS TUBOS
#     * EL CANTON
#     * HUAXTLA
#     * PERULA
#     * EL AGUACATE
#     * MIRADOR DE SAN ISIDRO
#     * FOVISSSTE ESTADIO
#     * SAGRADO CORAZON
#     * LOPEZ DE LEGASPI
#     * SANTA RITA
#     * CANAL 58
#     * COLOMOS PROVIDENCIA
#     * MISION DEL BOSQUE
#     * MARCELINO GARCIA BARRAGAN
#     * REAL VALLARTA
#     * VISTAS DE TESISTAN
#     * HACIENDA DEL TEPEYAC
#     * VICTOR HUGO
#     * CONCEPCION DEL VALLE (LA CONCHA)
#     * NUEVO MEXICO
#     * LOMAS DEL SEMINARIO
#     * PRADOS TEPEYAC
#     * LOS PINOS
#     * SAN JOSE DEL BAJIO
#     * VALLE DE LAS FLORES
#     * RDA DEL AUDITORIO
#     * FRACC REAL DEL VALLE
#     * POPULAR No 9
#     * PANORAMICA DE HUENTITAN
#     * LOS OCAMPO
#     * VISTAS DEL PEDREGAL I
#     * CAMPO REAL
#     * SAN JOSE DEL VALLE
#     * MEDRANO
#     * TOLOLOTLAN
#     * INDUSTRIAL ZAPOPAN NORTE
#     * RANCHO BLANCO
#     * VALLE DEL ALAMO
#     * PARQUES DEL PALMAR
#     * LAZARO CARDENAS DEL RIO
#     * CAMICHINES II
#     * LA PALMITA
#     * ALTOS NORTE
#     * DEL BARRO
#     * SANTA MONICA
#     * PRADOS DEL NILO
#     * MISION  ACUEDUCTO
#     * LA QUINTA CATALINA
#     * LA CASTILLA
#     * SAN FRANCISCO DE LA SOLEDAD
#     * VISTA DEL PINAR
#     * CORDILLERAS
#     * PLAZA GUADALUPE
#     * PASEOS DE LA HACIENDA
#     * CIRCUNVALACION AMERICAS
#     * JUAN MANUEL
#     * JARDINES DE LAS FUENTES
#     * MOCTEZUMA
#     * JARDINES DE LA REINA
#     * LOMAS DE SAN MIGUEL II
#     * ARBOLEDAS SUR
#     * CIMA DEL SOL
#     * COLON INDUSTRIAL
#     * CASA BLANCA
#     * LA RIOJA
#     * POSTES CUATES
#     * JARDINES DE GUADALUPE
#     * VISTAS DEL VALLE (VILLAS DE SAN SEBASTIAN)
#     * ALAMO LOMAS
#     * PROVIDENCIA 3a SECCION
#     * COLINAS DE LAS AGUILAS
#     * LOS GIRASOLES
#     * VISTAS DEL VALLE
#     * VILLA CALIFORNIA
#     * AYUNTAMIENTO
#     * PUNTA CORAL AQUA
#     * REAL DEL BOSQUE
#     * LOMAS DE ATEMAJAC
#     * BOSQUE ESCONDIDO
#     * GIRASOLES ACUEDUCTO
#     * VENUSTIANO CARRANZA
#     * SANTA CRUZ DE LA LOMA (TEPETATES)
#     * PUERTA SERENA
#     * PUERTAS DEL ANGEL
#     * VILLAS SAN MIGUEL
#     * JARDINES DE LOS POETAS
#     * VILLAS DEL ORIENTE II
#     * PARQUE METROPOLITANO
#     * COLOMOS
#     * BRISAS DE LA PRIMAVERA
#     * LA NORMAL
#     * CAMPO SUR
#     * RINCONADAS DEL SOL
#     * REPUBLICA
#     * LOS TULIPANES
#     * COLINAS DE LA PRIMAVERA
#     * ARBOLEDA
#     * BASE AEREA MILITAR NO 5
#     * SANTA FE
#     * CRUZ DE LA LOMA
#     * VALLE DEL SOL
#     * EL CENTINELA
#     * PARQUES DE SANTA MARIA
#     * MISION MAGNOLIA
#     * VALLE DE LA PROVIDENCIA
#     * AUTOCINEMA
#     * TERRANOVA
#     * JARDINES DE LA BARRANCA
#     * FIDEL VELAZQUEZ
#     * TALPITA
#     * LOMAS DE PROVIDENCIA
#     * PARQUE INDUSTRIAL EL ALAMO
#     * PRIMAVERA NORTE
#     * DE LA PRESA
#     * CHAPALITA DE OCCIDENTE
#     * PUERTA DEL BOSQUE
#     * LOS CHARCOS
#     * VILLAS DE SAN JUAN
#     * UAG
#     * HOGARES DE NUEVO MEXICO
#     * LOMAS DE HUISQUILCO
#     * PUEBLITO DEL SOL
#     * JARDINES DE TABACHINES
#     * VILLAS DE TESISTAN
#     * VILLAS ALCALDE
#     * BALCONES Y/O PRADOS DE HUENTITAN
#     * ELECTRICISTAS
#     * VILLA FONTANA DIAMANTE
#     * RIO VERDE
#     * JARDINES ALCALDE
#     * LOMA BONITA SUR
#     * SAN JUAN DE OCOTAN 2
#     * ARROYO SECO
#     * MIRADOR SAN ISIDRO
#     * VALLE IMPERIAL
#     * VILLAS DEL BOSQUE
#     * PARQUES TEPEYAC
#     * LA HACIENDITA
#     * ZAPOPAN
#     * LAZARO CARDENAS (BARRANQUITAS)
#     * JARDINES DEL PARAISO
#     * MOLINO DEL SALVADOR
#     * INFONAVIT INDEPENDENCIA
#     * HACIENDAS GUADALUPE
#     * ZAPOPAN CENTRO
#     * LAS GALEANAS
#     * FRACCIONAMIENTO LOS PRADOS
#     * SAN JUAN DEL RIO
#     * EL COLIBRI
#     * VILLAS DE LA TIJERA
#     * SANTILLANA
#     * PROVIDENCIA 2a SECCION
#     * JARDINES DEL PORVERNIR
#     * COLINAS DE LA CRUZ
#     * HOGARES DEL BATAN
#     * LAS PUERTAS
#     * BOSQUES DEL BOULEVARD
#     * JARDINES DEL TAPATIO
#     * LAURELES
#     * JUAN GIL PRECIADO
#     * FUENTE MAYOR
#     * OBELISCOS
#     * ALFREDO BARBA
#     * LOMA DE LOS PAJAROS
#     * PASEOS DE LA CAÑADA
#     * VILLAS DEL IXTEPETE
#     * VILLAS VALLARTA
#     * VALLE DE LAS HERAS
#     * VALLARTA UNIVERSIDAD
#     * LA PILA
#     * FEDERALISMO
#     * JARDINES DE LA PATRIA
#     * JARDINES DE LA ESPERANZA
#     * PRADOS PROVIDENCIA
#     * PORTA REAL
#     * MARGARITA MAZA DE JUAREZ
#     * LA CAMPESINA
#     * VILLAS DE ZALATITAN
#     * SENDERO DE LAS MORAS
#     * PLAN DEL RIO
#     * FLORES MAGON
#     * EL CAPULLO
#     * AGUA BLANCA SUR
#     * LA EXPERIENCIA
#     * UNIVERSITARIA
#     * VALLARTA CUAUHTEMOC
#     * JARDINES TEPEYAC
#     * LOS MEZQUITES 2
#     * LA GIRALDA
#     * VALLE DE SAN ISIDRO
#     * BALCONES DE HUISQUILCO
#     * SAN MARINO
#     * JARDINES DE CHAPALITA
#     * EL TRAPICHE
#     * VILLAS DE LA ALAMEDA
#     * EL RECODO
#     * FRACC PASEOS DEL PEDREGAL
#     * MESA DE LOS LAURELES
#     * BOSQUES DE SAN MARTIN
#     * JAZMIN
#     * POLIGONO FABRICA AGYDSA
#     * RINCON DE LA AGUA AZUL
#     * ALTOS ORIENTE
#     * EL CARMEN HABITAT
#     * DE LOS SAUCES
#     * DE LAS AURORAS
#     * HACIENDAS DEL REAL
#     * PARQUE ARRAYANES
#     * VILLAS PERISUR
#     * INDUSTRIAL LOS BELENES
#     * COLINAS DE SAN JAVIER
#     * VALLE DE LOS SAUCES
#     * FRACCIONAMIENTO CASA BLANCA
#     * BOSQUES DEL ENCINO
#     * BELENES NORTE
#     * LA CAÑADA
#     * LOMAS DE GUADALUPE
#     * HACIENDA DE SAN MARTIN
#     * EL CERRITO DE LA REYNA
#     * PINO SUAREZ
#     * EL TRECE
#     * BONANZA
#     * CASTRO URDIALES (PACANA)
#     * TEPEYAC CASINO
#     * COLLI PRIMAVERA
#     * PARQUES DEL NILO I
#     * JARDINES DE SAN SEBASTIAN
#     * LOS ALCATRACES
#     * LAGUNAS
#     * REAL PATRIA
#     * BOSQUES DE LA ESPERANZA
#     * GUSTAVO DIAZ ORDAZ
#     * RINCON DE LOS COPALES
#     * VILLAS DEL PALMAR
#     * EL REHILETE
#     * PLAN DE LAS FLORES
#     * HACIENDAS DEL SUR
#     * JOSE VASCONCELOS
#     * LOMAS DE SAN PEDRO
#     * CONCHITAS
#     * MISSION SAN FRANCISCO
#     * VIVEROS DEL VALLE
#     * DE SANTIAGO
#     * VALLE DE SAN NICOLAS
#     * HUERTA BAEZA
#     * TONALA
#     * FRACC VISTAS DEL VALLE
#     * LAS TROJES
#     * BOSQUES DEL SOL
#     * HACIENDA DEL CAMICHIN 8470
#     * LOS ENCINOS
#     * POPULAR
#     * HORIZONTE EL TAPATIO
#     * CLUB DE GOLF ATLAS
#     * LOMAS DE TONALA
#     * PRADOS GUADALUPE
#     * ITALIA PROVIDENCIA
#     * FABRICA DE ATEMAJAC
#     * RENACERES
#     * JARDINES DEL VIGIA
#     * SECCION Y22
#     * HEROES NACIONALES
#     * JARDINES DE SAN RAFAEL
#     * CIRCUNVALACION VALLARTA
#     * DE LA AZALEA
#     * AGRARIA
#     * VOLCAN DEL COLLI
#     * FLORES DEL VALLE
#     * EL ROCIO
#     * CORTIJO SAN AGUSTIN
#     * DEL ANGEL RESIDENCIAL
#     * BOSQUE DE LOS VIRREYES
#     * VISTAS DEL PEDREGAL
#     * LA CASTELLANA
#     * PARQUES DEL CENTINELA
#     * HORIZONTES DE TLAQUEPAQUE
#     * LAS LOMAS
#     * NOVATERRA
#     * PARQUE REGENCY
#     * PASEOS DEL BRISEÑO
#     * MISION DEL VALLE
#     * LOS NOGALES
#     * HACIENDA AGAVES
#     * JARDINES DE LA SEATTLE
#     * SAN WENCESLAO
#     * AMARANTO
#     * LOS PAJARITOS
#     * BOSQUES DE SANTA ANITA
#     * LOS CONEJOS
#     * LOMAS DE SAN PEDRITO
#     * EL PANORAMICO II
#     * XICOXOCHITL
#     * VERDE VALLE
#     * JUAN MANUEL VALLARTA
#     * POPOTES
#     * SAN IGNACIO CERRO GORDO
#     * JOSEFINO DE ALLENDE (ALLENDE)
#     * LA PRESA
#     * CAPILLA DE MILPILLAS
#     * TIERRAS BLANCAS
#     * JESUS MARIA
#     * LOS SAUCES DE ARRIBA
#     * EL DEPOSITO
#     * JARDINES DE ORIENTE
#     * LA TINAJITA
#     * JARDINES DEL ROSAL
#     * LA CALZADA
#     * LOS ADOBES
#     * RASTRO
#     * PEGUEROS
#     * LOS LLANITOS
#     * TIERRAS COLORADAS
#     * LA GLORIA
#     * COMERCIAL DEL SUR
#     * LOS ARROYOS
#     * DEPOSITO
#     * CERRITO DE LA CRUZ
#     * NUEVA ESPAÑITA
#     * HUISQUILCO
#     * CALZADA LA GLORIA
#     * SANTA MARIA DE GUADALUPE
#     * LAGUNILLAS
#     * DE LA CRUZ
#     * INTERLOMAS
#     * SAN ANTONIO EL ALTO
#     * SAN JOSE DE LOS REYNOSO
#     * JARDINES DEL REAL
#     * SAN GASPAR DE LOS REYES
#     * LOMAS DE LA PRESA
#     * SIERRA HERMOSA
#     * LOS CUERVITOS
#     * BOSQUES DEL LAGO
#     * EL REALENGO
#     * SANTIAGUITO DE VELAZQUEZ
#     * PASEO DEL LAGO
#     * LAS CALLES DE ALCALA
#     * RESIDENCIAL GUADALUPE II SECCION
#     * INFONAVIT LOS CONEJOS
#     * SAN ANGEL
#     * RIBERAS DE MEXIQUITO
#     * ESPAÑITA
#     * TEPATITLAN DE MORELOS
#     * HACIENDA LA GLORIA
#     * TECOMATLAN
#     * SAN NICOLAS DE LAS FLORES
#     * EL TANQUE
#     * LAS CAPUCHINAS
#     * TORRECILLAS
#     * BETULIA
#     * BAJO DE MOYA
#     * LA ISLA
#     * LAGOS DE MORENO
#     * LA LAGUNA (EL BAJIO)
#     * CAÑADA DE RICOS 2
#     * MI NUEVO SAN JUAN
#     * INDECO
#     * EL HERRERO
#     * PEDREGOSO
#     * ENCARNACION DE DIAZ
#     * COLINAS DEL VALLE
#     * DIECIOCHO DE MARZO
#     * CUESTA BLANCA
#     * JARDINES DE VISTA HERMOSA
#     * PRIMERO DE MAYO
#     * SAN ANTONIO BUENAVISTA
#     * EL MEZQUITAL
#     * DEL PANTEON
#     * LOS LAGOS
#     * LAURELES DEL CAMPANARIO
#     * CHINAMPAS
#     * EL OJUELO
#     * RIO ZULA II
#     * CHICHIMECO
#     * LA RIBERA
#     * ANAHUAC
#     * CIENEGA DEL PASTOR
#     * JOSE MARIA MORELOS
#     * LA VILLA
#     * VILLAS DE ZULA
#     * MAGUEYERA
#     * EL POTRERO
#     * SAN SEBASTIAN SANTULAPAN
#     * NUESTRA SEÑORA DE LOURDES
#     * GUADALUPE DE LERMA
#     * SAN JOSE CASAS CAIDAS
#     * OJO DE AGUA DE MORAN
#     * TORRECILLAS SUR
#     * GUADALUPANA
#     * SAN LUIS DEL AGUA CALIENTE
#     * INFONAVIT PROGRESO
#     * EL FUERTE
#     * SAN JERONIMO
#     * SIN NOMBRE
#     * LOS NARANJOS
#     * MARCOS CASTELLANOS
#     * LA COLONIA
#     * OTATLAN
#     * MALTARAÑA (LA PALMITA)
#     * EL AGUACALIENTE
#     * LABOR VIEJA
#     * VALLE DE JUAREZ
#     * SANTA ANA
#     * JARDINES DEL CASTILLO
#     * MAZAMITLA
#     * LA HUIZACHERA
#     * PRADOS DE EL VERDE
#     * GASTRONOMICA
#     * EL ATRACADERO
#     * LA PLAYA
#     * RIBERA DEL PILAR
#     * ATEQUIZA
#     * RIVERAS DE SAN IGNACIO
#     * DAVALOS FLORES
#     * EL CHARCO
#     * SAN JUAN CITALA
#     * GUIZAR
#     * ALTUS BOSQUES
#     * TUXCUECA CENTRO
#     * ESTIPAC
#     * LOS GRANADOS
#     * LA HIERBABUENA SUR
#     * JUANACAXTLE
#     * SAN JOSE DE LOS POZOS
#     * ALVAREZ DEL CASTILLO
#     * TIERRA BLANCA
#     * LA CRISTIANIA
#     * PUERTA DE CITALA
#     * HACIENDA SANTA ANA
#     * DAVALOS FLORES SUR
#     * LOS CORTEZ
#     * DE SANTA ANA
#     * EL CASTILLO 1
#     * LOS CEDROS
#     * ZAPOTILTIC
#     * LOS CAMICHINES
#     * EL LINDERO
#     * MAGISTERIAL
#     * EL CALABOZO
#     * UNION DE GUADALUPE
#     * QUITUPAN
#     * EL ROBLE
#     * EL NARANJITO
#     * ASCENCION
#     * 5 DE NOVIEMBRE
#     * CRUZ BLANCA CENTRO
#     * LOS DORADOS DE VILLA II
#     * LA CANDELARIA
#     * CIUDAD GUZMAN
#     * CRUZ VERDE
#     * INFONAVIT (ESTANCIA)
#     * SAN LUCAS
#     * EL PASTOR DE ARRIBA
#     * CENTRO HISTORICO
#     * LOMAS DE SAN CAYETANO
#     * ATOYAC CENTRO
#     * SENDEROS SAN MIGUEL
#     * VILLAS LA ALAMEDA
#     * CRUZ VERDE 2
#     * ATEMAJAC DE BRIZUELA CENTRO
#     * CLAVELLINAS
#     * LA CANTERA SAN JOSE
#     * UNION DE COLONOS INDEPENDENCIA
#     * SAN MARCOS EVANGELISTA
#     * PABLO LUIS JUAN
#     * LOMAS DE SOLIDARIDAD
#     * ANTONIO GANDARA ESTRADA
#     * ALISTA
#     * LAS MARGARITAS
#     * JUAREZ
#     * PARAJES
#     * COLINDE
#     * UNIVERSITARIA 2
#     * LOS ENCINOS I,II,III
#     * PROVIPOSA
#     * CUYACAPAN
#     * PRIMAVERA
#     * LAS CEBOLLAS CENTRO
#     * EL FRESNITO
#     * JARDINES DE ZAPOTLAN
#     * LA GRANA PONIENTE
#     * LA QUEBRADILLA
#     * LOS ARQUITOS
#     * LLANOS DEL COAJINQUE
#     * CERRO COLORADO 2DA SECC
#     * LOS ARQUITOS CENTRO
#     * COLINAS DEL SUR
#     * AYOTITLAN
#     * LA PALOMA
#     * JARDINES DE AUTLAN
#     * VALLE DEL VERGEL
#     * CHAPINGO
#     * EFRAIN GONZALEZ LUNA
#     * IPEVI
#     * COLONOS ALAMEDA
#     * PATRIA
#     * EL CHACALITO
#     * CASTELLON
#     * EL MENTIDERO
#     * LAS CEIBAS
#     * VILLAS DE AUTLAN
#     * LA UNIDAD
#     * VILLAS DE PUERTO
#     * EL MANGAL
#     * NUEVO IXTAPA
#     * LOMAS DEL CALVARIO
#     * HACIENDA SAN NICOLAS
#     * BALCONES DE VALLARTA
#     * 24 DE FEBRERO
#     * BOCA DE TOMATLAN
#     * PASEOS UNIVERSDAD II
#     * LA TRINIDAD
#     * PASO DEL GUAYABO
#     * EL LLANITO
#     * VILLAS DEL MOLINO
#     * POBLADO DE LAS PALMAS
#     * EL REMANCE
#     * LAS ARALIAS
#     * BOSQUES DEL PROGRESO
#     * LAGUNA DEL VALLE
#     * JARDINES DE LA HIGUERA
#     * VALLARTA 500
#     * VILLAS UNIVERSIDAD
#     * VILLAS DEL REAL
#     * ALBATROS
#     * LA MINA
#     * AMAPAS
#     * VILLAS LAS PALMAS
#     * ARAMARA
#     * FOVISSSTE 96
#     * AGUA ZARCA
#     * JARDINES DEL PUERTO
#     * FOVISSSTE 100
#     * AGUA AZUL
#     * CAMPESTRE LAS CAÑADAS I
#     * LA NEGRA
#     * LOS CAJOS
#     * CAMPESTRE SAN NICOLAS
#     * VISTA VOLCANES
#     * PUERTO VALLARTA
#     * PASO ANCHO
#     * PALMAR DE ARAMARA
#     * EL CIELO
#     * RANCHO CORONA
#     * LA REYNA
#     * LA SAUCEDA
#     * LAS LADRILLERAS
#     * PLAYAS DEL POZONEXTLE
#     * LA GUITARRILLA
#     * LA CIENEGA
#     * SAN ANTONIO MATUTE
#     * LABOR DE MEDINA
#     * MIXTLAN CENTRO
#     * EL CABEZON
#     * LOMAS DE COCULA
#     * LA VILLITA
#     * PUERTA DEL BORREGO
#     * JAVIER SAUZA
#     * LLANO CHICO
#     * GUACHINANGO CENTRO
#     * CUISILLOS CENTRO
#     * JACARANDAS
#     * LA ALTAMIRA
#     * EL TEMPIZQUE
#     * LOMAS DE TEUCHITLAN
#     * MEZQUITES 1
#     * NAVAJAS
#     * OBRERA 1
#     * SAUZA
#     * JARAMILLO
#     * AHUISCULCO
#     * EL TRAPICHE (TRAPICHI)
#     * LA QUEMADA
#     * ESPINOS
#     * LA ESTANCIA (LA ESTANCITA)
#     * LOMAS DE AYAHUALULCO
#     * AHUALULCO ORIENTE
#     * SAN ISIDRO MAZATEPEC
#     * MANUEL M DIEGUEZ
#     * COPAL
#     * SAN IGNACIO EMILIO PORTES GIL
#     * TEXCALAME
#     * LA MAZATA
#     * ESTACION
#     * NUEVO TLAXCALA 2
#     * SANTIAGO TLALTELOLCO
#     * DEL CERRITO
#     * TENZOMPA
#     * DE LA PIEDRA CHINA ORIENTE
#     * AGUSTIN CALOCA
#     * TEMACHACO
#     * PUERTA DEL CEDRO
#     * JOSE MARIA PRECIADO
#     * SAN PATRICIO (MELAQUE)
#     * HERMENEGILDO GALEANA
#     * JARDINES DE PURIFICACION
#     * EL MAGUEY
#     * LO ARADO
#     * ZAPOTAN
#     * JOSE MARIA MARTINEZ
#     * JUAN FERNANDEZ DE HIJAR
#     * PLAN DE AYALA
#     * LAGUNILLAS DE MACUACA (LAGUNILLAS)
#     * LA GLORIA SUR
#     * MEXICO CHICO
#     * LA LUZ
#     * HUACHILISCO
#     * LA PREPA
#     * LAS AMERICAS
#     * HACIENDA POPOTES
#     * JARDINES DE TEPA
#     * LOS ARCOS
#     * SANTA ELENA
#     * TEPUSCO
#     * MUNICIPIO LIBRE
#     * LOMAS DE LA ESTACION
#     * PUENTE CHICO
#     * EL RANGEL
#     * LOS AZULITOS
#     * TACUBAYA
#     * RANCHO VIEJO
#     * MILPILLAS
#     * EL NUEVO VALLE
#     * PASO BLANCO
#     * SAN JUAN TECOMATLAN
#     * SANTA CRUZ (EL GRANDE)
#     * INFONAVIT VISTAS DEL MAGUEY
#     * EL BELEN
#     * LA LOMA II
#     * EL TEPEHUAJE DE MORELOS
#     * EL TEZCALAME
#     * CONCEPCION DE BUENOS AIRES
#     * ROSENDO G CASTRO
#     * LOMA DE SANTA CRUZ
#     * SAN LORENZO
#     * LOS VELEROS
#     * BARRANCA DE OTATES
#     * LA NUEVA LUZ
#     * HIJOS ILUSTRES DE ZAPOTLAN
#     * SAN ANDRES IXTLAN
#     * ADOLFO LOPEZ MATEOS
#     * CTM
#     * PALMITA
#     * CONTLA
#     * ISSSTE
#     * STA MA DEL VALLE DE GPE
#     * LOS CALLEJONES
#     * EL PITAYO
#     * COAHUAYOTE DEL ARCO
#     * MANSIONES DEL REAL
#     * LA VIRGEN
#     * EL GARGANTILLO
#     * VALLARTA VILLAS
#     * EL RANCHITO COLEXIO
#     * GARZA BLANCA
#     * PARQUE LAS PALMAS
#     * SANTUARIO
#     * PONDEROSA
#     * CAMPESINA
#     * JARDINES DE SAN JAVIER
#     * MAYAHUEL
#     * BICENTENARIO
#     * PRESIDENTES
#     * LA MORENA
#     * CHACALA
#     * PRADERAS DE LA ALAMEDA
#     * PONCIANO ARRIAGA
#     * LA ARBOLEDA
#     * SOLEDAD DE CRUZ VIEJA
#     * RANCHO CONTENTO
#     * LAS FUENTES
#     * BUENA MIRADA
#     * BRISAS DE CHAPALA
#     * LA SELVA
#     * FRACC LOMAS DE LA CAPILLA
#     * CHAPULIMITA
#     * JARDIN ESPAÑOL
#     * LA ESTANCIA DE LANDEROS
#     * CONJUNTO PATRIA
#     * CIUDAD DE LOS NIÑOS
#     * EUCALIPTO VALLARTA
#     * DEL SOL
#     * EL TRIANGULO
#     * GUADALUPE JARDIN
#     * PRADERAS DE TESISTAN
#     * LOS PERIODISTAS
#     * INFONAVIT EL TABLON
#     * HACIENDA DE BRAVO
#     * LA JOYITA
#     * LOS OCOTILLOS
#     * BARRIO ALTO
#     * ARCOS DE LA CRUZ
#     * UNIDAD CADETE FCO MARQUEZ
#     * RINCON DEL BOSQUE
#     * QUINTAS DEL BOSQUE
#     * EL TEPAME
#     * JARDINES PLAZA DEL SOL
#     * LOS GAVILANES
#     * LAGO NOGAL
#     * CERRO DEL JAGUEY
#     * MERIDIANO (HOGARES DEL ALAMO)
#     * SOLE REAL
#     * ACUEDUCTO SAN AGUSTIN
#     * VIRREYES
#     * VALLE DE ATEMAJAC
#     * LOS FRAILES
#     * LOMAS DE SANTA ANITA
#     * LAS GRANJAS
#     * ARCOS
#     * PRADOS VALLARTA
#     * PINAR DE LA VENTA
#     * BUGAMBILIAS COUNTRY
#     * ECOLOGICA EL SEATTLE
#     * COLINAS DE TONALA
#     * VISTAS DEL NILO
#     * FRACCIONAMIENTO GEOVILLAS ARBOLADAS PLUS
#     * LORETO
#     * LOMAS ALTAS
#     * CANTERAS DEL CENTINELA
#     * SAN MARTIN DEL TAJO
#     * VALLE ESMERALDA
#     * SAN ISIDRO RESIDENCIAL
#     * LAS TERRAZAS
#     * HACIENDA SAN ANTONIO
#     * DEL PARQUE
#     * LAS ALAMEDAS
#     * MODELO
#     * CERRO DEL TESORO
#     * OBLATOS PTE
#     * BOSQUE DE LOS COLOMOS
#     * LA TOSCANA
#     * BOSQUE DE VALDEPEÑAS
#     * PUERTA DE PLATA
#     * LOMA BLANCA
#     * JARDINES SEATTLE
#     * JERICO
#     * RESIDENCIAL ARRAYANES
#     * HACIENDA SAN AGUSTIN
#     * PUERTA DEL ROSARIO
#     * FRACC  RESIDENCIAL AMANECERES
#     * PUERTA DEL LLANO
#     * COLLI
#     * VILLA VERONA
#     * SENDERO REAL
#     * LAS GRULLAS
#     * GUSA
#     * GALERIAS
#     * JARDINES DE LA RIVERA
#     * RESIDENCIAL DEL CARMEN
#     * VILLAS DE SANTA SOFIA
#     * LAS ROSAS ORIENTE
#     * CENTRO 2
#     * DE LAS LOMAS
#     * EL SEMINARIO
#     * TECALITLAN
#     * VILLAS DE ZAPOTLAN
#     * BENEFACTORES
#     * SAN JUAN ESPANATICA
#     * LAS MONTAÑAS
#     * EX HACIENDA EL PITILLAL
#     * RESIDENCIAL LAS GAVIOTAS
#     * VALLARTA 750
#     * VILLAS DEL MAR
#     * 2 DE FEBRERO
#     * MADRE LUISITA DE LA PEÑA
#     * GRANJA ASTURIAS
#     * SOLIDARIDAD LA PAZ 2a ETAPA
#     * PIEDRA PESADA
#     * GIRASOLES ELITE
#     * SANTA ROSA II
#     * PRADOS DE LA HIGUERA
#     * HACIENDA SAN PEDRO
#     * HACIENDA DEL ORO
#     * PRADOS DE NEXTIPAC 2a SECCION
#     * ALTUS QUINTAS
#     * LAS CUMBRES
#     * ESPAÑA
#     * BALCONES DE LA JOYA
#     * COLINA REAL
#     * SUPER MANZANA EL ALAMO
#     * LA CONCHA JARDIN RESIDENCIAL
#     * LA CUCHARA
#     * VALLE DE TLAJOMULCO
#     * PEDREGAL DE SANTA MARTHA
#     * GEO VILLAS DEL REAL
#     * SENDAS
#     * BALCONES DE SANTA CRUZ
#     * VALLE DEL PARAISO
#     * TIERRA RESIDENCIAL
#     * SANTA MA DE SILO
#     * ELEMENT
#     * SAN MARTIN I
#     * LOS MANZANOS
#     * ESMERALDA
#     * LOS TELARES
#     * SAN MIGUEL RESIDENCIAL
#     * LOS LAURELES
#     * PLUTARCO ELIAS CALLES
#     * LAS LUCES
#     * VILLAS SANTA SOFIA
#     * ELITE
#     * PIRAMIDES
#     * LOTE
#     * RINCONADAS DEL SOL 2
#     * PARQUE DE LA CASTELLANA
#     * SAN DIEGO
#     * JARDINES DEL PRADO
#     * HACIENDA SAN MIGUEL
#     * PINAR DE LAS PALOMAS I
#     * AUTODROMO
#     * SAN MIGUEL DE LA COLINA
#     * GUADALUPE INN
#     * LA VINATERIA
#     * HACIENDA DE LAS LOMAS
#     * DEL VALLE
#     * INFONAVIT SAN AGUSTIN DE LAS FLORES
#     * MOCTEZUMA PTE
#     * MAGISTERIAL VALLE DE SAN ISIDRO
#     * OBSERVATORIO
#     * EL LIMON
#     * LOS GAVILANES PONIENTE
#     * LOS CIRUELOS
#     * CAMICHINES III
#     * PRADERAS DEL SOL
#     * PUERTA DEL VALLE
#     * ARCOS DE SAN SEBASTIAN
#     * VILLA DE SAN MIGUEL CUYUTLAN
#     * PRADOS DE SANTA MARIA
#     * LOS LIMONES
#     * RINCONADA DE LOS NOGALES
#     * VILLA LA CIMA
#     * EL TRIGO
#     * PARAISO LOS PINOS
#     * VILLAS DEL EDEN
#     * CAMICHIN SANTA ANITA
#     * EL JORDAN
#     * LOS MAGUEYES
#     * LOS CASTAÑOS
#     * ARCOS DE ZALATITAN II
#     * PLAYAS DE CAJITITLAN
#     * VALLE DEL SUR
#     * JARDINES DEL IXTEPETE
#     * RINCONADAS DEL AIRE
#     * GUADALAJARITA
#     * SAN JOSE DEL RIO
#     * PALERMO
#     * QUINTAS DEL PARAISO
#     * LAS PALOMAS
#     * CIMA REAL
#     * VILLAS DE SANTA ANITA
#     * JARDINES DE LA ALAMEDA
#     * VILLA BONITA
#     * NUEVO AMANECER
#     * COLINAS DE CRISTO REY
#     * CAÑADAS DE SAN LORENZO
#     * LUCERO DEL VALLE
#     * EL ORIGEN RESIDENCIAL
#     * JARDINES DE LA GLORIETA
#     * MECHOACANEJO
#     * EL ARENAL
#     * BELEN DEL REFUGIO
#     * VILLA DEL SOL
#     * DE PADRE TORRES
#     * NUEVO SANTA ELENA
#     * EL PLATANAR
#     * AHUATLAN
#     * SAN JAVIER
#     * SANTA ROSA DE LIMA
#     * PASO DE PIEDRA
#     * NUEVO CHAPALA
#     * JARDINES DEL VERDE EJIDAL
#     * LA PAROTA
#     * 16 DE SEPTIEMBRE
#     * EL CORTIJO
#     * CENTRO 2DA SECC
#     * PUERTA DE LA COSTA
#     * JARDINES DE SANTA RITA
#     * PINTORES SUR
#     * RESIDENCIAL EL PARAISO
#     * 10 DE MAYO
#     * EL CONEJO
#     * JARDINES DE LAS GAVIOTAS
#     * REAL IXTAPA
#     * NUEVO NAHUAPA
#     * LINDAVISTA OCEANO
#     * VALLE DEL MAR
#     * LA LABOR DE SOLIS
#     * PLAYA DEL RIO
#     * CAMAJAPA
#     * INFONAVIT
#     * JOSEFA ORTIZ DE DOMINGUEZ
#     * BAJIO
#     * PUESTA DE SOL
#     * LA ESCONDIDA
#     * EL CERRO
#     * LA ORILLITA
#     * FAUSTO QUINTERO
#     * PUERTA GRANDE
#     * CORTIJO
#     * LOMAS DE ORIENTE
#     * NUEVO TLAXCALA
#     * EL VALLADO SUR
#     * CUARTO CENTENARIO
#     * EL TEPEC
#     * EL RIO DESARROLLO ECOLOGICO
#     * VILLA ESMERALDA
#     * LA CANTERA (LA CANTERA DE MORENO)
#     * LA CUESTA DE MEZCALA
#     * PUEBLO BONITO
#     * LA RESOLANA
#     * SAN SEBASTIAN
#     * TACOTAN
#     * VILLAS TAURINAS
#     * ISLA IGUANA
#     * EL MALVASTE
#     * EL REBALSITO (GRAL LAZARO CARDENAS)
#     * CASIMIRO CASTILLO
#     * CHAPALITA LAS FUENTES
#     * PRIVANZA
#     * COATLANCILLO
#     * MISION LA FLORESTA
#     * CUMBRES DEL NILO
#     * LA ROCA
#     * FORET
#     * COLINAS DE SANTA ANITA
#     * VALLE NORTE
#     * LARGUERO
#     * LA MORALEJA
#     * LOS TEPETATES
#     * HIELERA
#     * EL CARRIL TAPATIO
#     * VALENTIN CAMPA
#     * PARQUE GUADALUPE
#     * SAN ARTURO
#     * POTRERO DE SAN FRANCISCO
#     * POTRERO LOS AMADOR
#     * LOMAS DEL FORTIN
#     * PUERTA SOL AUTOPISTA
#     * DE LAS AZALEAS
#     * PASEOS DE TONALA
#     * ACUEDUCTO SAN JAVIER
#     * BOSQUES VALLARTA
#     * SANTOS DEGOLLADO
#     * COLLI SITIO
#     * JOYAS DEL NILO
#     * RESERVA LAS MAGNOLIAS
#     * FLAMINGO
#     * PRADOS TLAQUEPAQUE
#     * DEL IRIS
#     * LAS LOMAS GOLF  HABITAT
#     * LAS VEGAS
#     * ARBOLEDAS DE TESISTAN
#     * MANANTIAL
#     * MITICA RESIDENCIAL
#     * SAN PATRICIO
#     * COLINAS DE TESISTAN
#     * NOVATERRA RESIDENCIAL
#     * COLIMILLA
#     * GONZALEZ ORTEGA
#     * TEOCALTITLAN DE GUADALUPE
#     * LAS GUERAS
#     * VILLAS DEL SOL
#     * LOMAS DE GALINDO
#     * EL CARMEN (BUENA VISTA)
#     * TECUALTITAN
#     * OLIMPICA SUR
#     * SAN ANTONIO DE FERNANDEZ
#     * LA CHARCA
#     * COLINAS DEL SOL
#     * EL CRUCERO
#     * SAN PEDRO TESISTAN
#     * PUERTA DEL SOL
#     * LA LOMITA
#     * LA PURISIMA Y LA CALABAZA
#     * CAPULINES NORTE
#     * LA AGUACATERA
#     * NUEVO CHULUAPAN
#     * LA PIÑUELA
#     * LOMAS DEL AIRE
#     * ALTAVISTA
#     * TABACHINES 2
#     * AREA MILITAR DE VALLARTA
#     * LAS CANOAS
#     * LA ERA
#     * DON BOSCO
#     * LOS GUAJES
#     * ACACIAS
#     * MILENIO
#     * COLINAS DEL ROSARIO
#     * LA VIBORA
#     * RESIDENCIAL HUERTA VIEJA
#     * VILLAS DEL MARQUEZ
#     * LOMAS DE SAN DIEGO
#     * JARDINES DE ELIZABETH
#     * LA NUEVA VICTORIA
#     * EL MORAL
#     * LA CARIDAD
#     * PUERTA LAUREL
#     * PRIVADAS DE LA REYNA
#     * ARMONIA
#     * SAN JORGE
#     * JARDINES DE SANTA ANITA
#     * SAUCILLO DE MALDONADO
#     * ALAMEDAS DE TESISTAN
#     * LA CUSPIDE
#     * JARDINES DE LA PRIMAVERA
#     * VILLAS DEL VALLE
#     * EL ZAPOTE I
#     * NATURA BOSQUE
#     * DE SAN SEBASTIAN
#     * DEMETRIO VALLEJO
#     * ALFARERA
#     * LA PLANCHA
#     * SENDEROS DE MONTE VERDE
#     * LOMA CHICA
#     * REAL TONALA
#     * PASEOS UNIVERSIDAD
#     * LAS MORAS
#     * MANALISCO
#     * CRUZ DE ZACATE
#     * OJO DE AGUA DE LATILLAS
#     * LA NUEVA CRUZ
#     * LOS VIVEROS
#     * CAMPESTRE LA GLORIA
#     * PORTAL LOS SAUCES
#     * JUAN PABLO II
#     * SAN JOSE DE BAZARTE (LA VILLA)
#     * EL PIPON
#     * COMARCAS FRANCESAS
#     * MEXIQUITO
#     * SAN MIGUEL EL ALTO
#     * PASEO DE LOS VIVEROS
#     * PRADOS DEL PARQUE
#     * VAQUERIAS
#     * HACIENDA LOS JACALES
#     * DE LA LUZ
#     * DEL AGUA
#     * CANALES
#     * SAN JOSE DE ORNELAS
#     * RINCON CHIQUITO
#     * LOS AGRICULTORES DE OCOTLAN
#     * SAN RAMON
#     * SAN PEDRO DE RUIZ
#     * EL NACIMIENTO
#     * SAN JACINTO
# ...
#     * EL RINCON DEL AGUA
#     * LIC BENITO JUAREZ
#     * PINAR DE LOS ESCRITORES
#     * 5 DE FEBRERO
#     * UNION DE COLONOS DE CIUDAD GUZMAN
#     * COFRADIA DE DUENDES
#     * SAN JUAN DE AMULA
#     * RESIDENCIAL ENTRE RIOS
#     * HEROES DE LA PATRIA
#     * EL PUENTE
#     * DE ABAJO
#     * SAN CAYETANO
#     * HEROES DE NACOZARI
#     * LOS PORTALES TLAQUEPAQUE
#     * PARQUE DE LAS AVES
#     * LOMAS DE SANTA TERESA
#     * LA MILPILLA
#     * EL ASERRADERO
#     * DON MARTIN
#     * LOS CAMPOS
#     * CIHUALPILLI
#     * PARQUE DE LAS AZALEAS
#     * BELLATERRA
#     * LA CEJA
#     * LAS GABRIELAS
#     * DEL MEZQUITE
#     * ALAMITOS
#     * VILLA GALICIA
#     * LA ESPAÑITA
#     * SAN JAVIER II SECCION
#     * SAN ALFONSO
#     * MIRANDILLA
#     * LA HERRADURA
#     * PEDREGAL
#     * EL ALCALA
#     * SAN MIGUEL DEL CUARENTA
#     * MISION DE SAN JUAN
#     * IPROVIPE SANTA TERESA
#     * JARDINES DE TOTOTLAN
#     * PORTEZUELO
#     * SANTA CLARA DE ZULA
#     * LAS JARAS
#     * GUADALUPANA NORTE
#     * LA MESA RESIDENCIAL
#     * VILLAS DE SAN ISIDRO
#     * VALLE DE LOS MANZANOS
#     * LOS NARANJITOS
#     * CAPULINES
#     * LOMAS DEL NORTE
#     * UNIVERSITARIOS
#     * GASTRONOMICOS
#     * DEL VILLAR
#     * CAMPO SANTO
#     * LOS TECOMATES
#     * BELLA VISTA
#     * EL TROMPO
#     * COLINAS DE CHAPALA
#     * ATEQUIZAYAN
#     * JUAN RULFO
#     * RESIDENCIAL PROVIDENCIA
#     * EL MONTE
#     * REAL DEL CAMICHIN 8469
#     * ILUSION LAS ANTENAS (CA?ADA DE PEREZ)
#     * LA CRUZ (LAS CRUCES)
#     * LAS PAREDES
#     * EL FRACCIONAMIENTO
#     * LA JUNTA DE LOS OCOTES
#     * ALBATERRA
#     * VILLAS DE ZAPOTEPEC
#     * PASEOS DEL CAMICHIN
#     * CRISTAL
#     * VIA NOVA
#     * DE LOS PINOS
#     * RESIDENCIAL BUGAMBILIAS ZAPOTLANEJO
#     * NUEVO TLAJOMULCO
#     * EL SANCHE
#     * DE LOS FRESNOS
#     * PAISAJES DEL TAPATIO
#     * PARQUE SERENO
#     * MISION SANTA ANA
#     * NUEVO PRIMAVERA
#     * DEL PILAR RESIDENCIAL
#     * SENDERO DEL VALLE
#     * PUERTA DEL ROBLE
#     * JARDINES DEL ORGANO
#     * ALTIPLANO
#     * LA LOMA ALTA
#     * DEL CARRIL
#     * FORESTA SANTA ANITA
#     * LA PRADA
#     * EL ARROYO
#     * VILLANOVA
#     * CALLEJON DEL BOSQUE
#     * VILLAS OTERO DE GUADALUPE
#     * PRADERAS TONALLAN
#     * EL TEMPISQUE
#     * SENDEROS DE TESISTAN
#     * SAN PEDRO Y SAN PABLO
#     * PEDREGAL DE SAN MIGUEL
#     * HACIENDA DE LA REYNA II
#     * SANTA BARBARA
#     * VALLEJO
#     * LAS BOMBAS
#     * OCOTIC
#     * TLACOTAN
#     * EL ARBOL
#     * EL RESCATE
#     * EL NEJAYOTE
#     * LAZARO CARDENAS (SAN JOSE)
#     * JARDINES DE SAN JUAN
#     * LAS MORAS 3 (EL PEDREGAL)
#     * LOS ANGELES (EL SABINO)
#     * DE VISTA HERMOSA
#     * MARAVILLAS DE SAN JUAN
#     * MARGARITAS
#     * EL LORETO (OCCIDENTAL)
#     * EL TARENGO
#     * MADRE LUISITA DE LA PE?A
#     * SAN JOSE BUENA AGUA
#     * CARROZAS
#     * GABRIEL LEYVA
#     * REAL DE LOS FRESNOS
#     * BOSQUES DE LA RIVERA
#     * LA CAMPANA 2
#     * VALLE DE LOS SABINOS II
#     * LOMAS DE IXTLAHUACAN
#     * VICENTE GUERRERO (SAN VICENTE)
#     * SANTA MARIA MAGDALENA
#     * LOS GUAYABOS
#     * EDUARDO ROMERO
#     * LAS ENCINAS
#     * 21 DE MARZO
#     * LA CEBADA
#     * SAN JOSE DEL CARMEN
#     * TEPEC
#     * OBRERA 2a ETAPA
#     * CONDOMINIO ACUEDUCTO SAN JOSE
#     * APANGO
#     * EL CACALOTE
#     * EL PASO REAL
#     * LA GRANA
#     * INFONAVIT (LA NORIA)
#     * LA ALDABA
#     * VILLASOL
#     * LOMAS DEL PROGRESO
#     * LOS DELFINES
#     * PLAYA GRANDE
#     * CAMPESTRE LAS CAÑADAS II
#     * RINCON DEL PUERTO
#     * VISTA DORADA
#     * LAS PRIMAVERAS
#     * LA CUESTA
#     * POSOS ZARCOS
#     * EL SABINO
#     * LOS VOLCANES
#     * EL SAUCILLO
#     * MUNICIPAL
#     * 32 BATALLON DE INFANTERIA
#     * SAN ISIDRO PALO VERDE
#     * LAS HIGUERITAS
#     * ESTANCIA DE AYLLONES
#     * LLANITO
#     * OCONAHUA
#     * CAÑITA
#     * MEGA PROYECTO 2000
#     * DIVINO ROSARIO
#     * GASOLINERA
#     * EL PILE
#     * PORFIRIO DIAZ
#     * LA MISION
#     * LOS CERRITOS
#     * EL SALVADOR
#     * DE LOS PEREZ
#     * DEL CANTERO
#     * EL SERAFIN
#     * DE LA ROSA
#     * BLANCO
#     * JARDINES SAN ROQUE
#     * MIGUEL HIDALGO VIEJO
#     * TEQUESQUITLAN
#     * EL ZAPOTILLO
#     * CUIDAD PERDIDA
#     * LOMAS DE TEOCALTICHE
#     * REAL SAN ELIAS
#     * EL GOBERNADOR
#     * SANTIAGO
#     * JARDINES DE TALPA
#     * CACALUTA (VILLITA)
#     * EL PAREJITO
#     * CANTORES
#     * TEJERIAS
#     * VILLAS DEL NEVADO
#     * IXTLAN
#     * TEPANTLA
#     * COSIO VIDAURRI
#     * LAS PAROTITAS
#     * SUAVE PATRIA
#     * AYUQUILA
#     * SAN RAFAEL DE LOS MORENO
#     * YELAPA
#     * ECOTERRA
#     * EL GUAMUCHIL
#     * AHUALULCO EJIDAL
#     * TEJONERA
#     * EL CHICO
#     * CASA BLANCA (REVOLUCION MEXICANA)
#     * LA VICTORIA
#     * MIRADOR DEL REY
#     * NUEVO SAN MIGUEL I
#     * SAN ANTONIO MAZATEPEC
#     * EXHACIENDA ZAPOTLANEJO
#     * SAN JOAQUIN ZORRILLOS
#     * LAGO DEL SOL
#     * EL CONSUELO
#     * JUCHITLAN
#     * REAL MARSELLA
#     * DEL ROSARIO
#     * SANTA TERESITA
#     * TAVARES
#     * SAUCILLO DE PRIMAVERA
#     * MEZCALA DE LA ASUNCION
#     * LA MEZA
#     * LOS ROMERO
#     * SAN IGNACIO
#     * EL NARANJO
#     * EL GAVILAN
#     * VILLAS DE AGUA BLANCA
#     * EJERCITO
#     * JARDINES DE ATOYAC
#     * OTILIO MONTAÑO
#     * IPROVIPE
#     * JALPA
#     * ORIENTE 2
#     * ETA
#     * LLANO GRANDE
#     * RANCHITO
#     * LAS ROSAS
#     * EL ESPINAL
#     * CAROLINA CARDENAS
#     * ATECONGO
#     * SANTA MARIA DEL ORO
#     * PLACITA
#     * EL SANJON
#     * HACIENDAS DE ZAPOPAN
#     * CERRO DEL GATO
#     * SANTA INES
#     * CUAUTITLAN
#     * SANTA MARIA DE ENMEDIO
#     * SANTIAGO TOTOLIMIXPAN
#     * SOLEDAD OCHOA
#     * HIGUERA
#     * LA CALAVERA
#     * VEINTIUNO DE NOVIEMBRE
#     * TENEXCAMILPA
#     * AEROPUERTO
#     * JARDINES DE TLAJOMULCO
#     * PRIVANZA LA CEIBA
#     * SAN MARTIN DE LAS FLORES
#     * PUERTA DEL PRADO
#     * LOMAS DE TESISTAN
#     * LAS JARDINERAS
#     * TERRONES O TECOLUTA
#     * 23 DE MAYO
#     * NUEVA COLONIA
#     * LA SECUNDARIA
#     * MASCUALA
#     * JARDINES DE SAN MIGUEL
#     * LA CAPILLITA
#     * EL MAGUEY (EL REFUGIO)
#     * NUEVA DE JACALILLO
#     * HACIENDA DE ADOBES
#     * VILLAS DEL SOL II
#     * LOS HALCONES
#     * JUAREZ (EL PUENTE)
#     * QUINTAS DEL CAMPESTRE
#     * LA TRINIDAD (TRINIDAD DEL LLANO)
#     * EL REFUGIO DE LOS BAJOS
#     * TECOLOTE
#     * VILLAS DE LA GRANJENA
#     * LA TUNA
#     * PASCUAL ROJAS
#     * LA PAZ DE MILPILLAS
#     * LOS GOBERNADORES
#     * CALERA DE ARRIBA
#     * NUEVO AMECA
#     * LOS COYOTES
#     * DE EL MUELLE
#     * BAJIO O BARRIO POBRE
#     * NUEVA VIZCAYA
#     * CUATEZQUITE
#     * LOS COLONOS
#     * ACUEDUCTO
#     * RINCONADAS DE LA PROVIDENCIA
#     * CONDOMINIO PASEO DE LAS CAÑADAS
#     * NARANJITOS
#     * ATACCO
#     * EL AJUSCO
#     * AMEZCUA
#     * LA CENTRAL
#     * BARRANCA DE LAURELES
#     * LA UREÑA
#     * LAS PUERTAS DE ATOYAC
#     * HACIENDA ORIENTE
#     * LA GAVILANA
#     * FATIMA
#     * DEL CANGREJO
#     * LA MARTINICA 2
#     * LOMAS DE SAN JOSE
#     * TEPOSPIZALOYA
#     * LA ALAMEDA 2
#     * SAN JUAN DE ABAJO
#     * TEQUESQUITE
#     * HACIENDA SAN JAVIER
#     * CAÑADAS
#     * TEBELCHIA
#     * VILLA CUERAMBARO
#     * SAN IGNACIO OJO DE AGUA
#     * EL AMARILLO
#     * LA RESURECCION
#     * EL MEZQUITILLO
#     * DEL REFUGIO
#     * MAGALLANES
#     * HUILACATITLAN
#     * MIRA FLORES
#     * EL BAJIO 2
#     * LA MESA DE LA CORONILLA
#     * PUNTA VALDEPEÑAS
#     * BOSQUE DEL CENTINELA II
#     * SENTIMIENTOS DE LA NACION
#     * LIBRAMIENTO SUR
#     * SAN BARTOLO
#     * EL PARDO
#     * PUERTA TESISTAN
#     * ROBERTO OROZCO
#     * COLINAS DE ALTAMIRA
#     * PROVENZA
#     * QUINTAS DE TATEPOSCO
#     * EL TERRON
#     * PARQUES DE TESISTAN III
#     * LOS ALAMOS
#     * SENDA
#     * LOMAS DE LA NORMAL
#     * FRANCISCO PRIMO DE VERDAD (CIENEGA DE MATA)
#     * ALTA VISTA
#     * MERCED SEDANO
#     * VOLCANES
#     * 9 DE OCTUBRE
#     * EL CASCO
#     * CERRITO
#     * LA ALCANTARILLA ( SAN FRANCISCO)
#     * VILLAS DE LA CRUZ (EL ROBLE)
#     * LADRILLERA
#     * VILLAS DE ASIS
#     * 3 FLORES
#     * NOCHE BUENA
#     * JARDINES DEL CASTILLO LAS CASUARINAS
#     * TEHUANTEPEC
#     * CENTRAL DE ABASTOS
#     * 7 DE ABRIL
#     * FUENTES DEL NILO
#     * PRADERAS DEL CENTINELA
#     * RINCONADAS DE LA PRIMAVERA
#     * OLIVOS RESIDENCIAL
#     * CAMPOS ELISEOS
#     * PIO XII
#     * RINCONADA LA MAJADA
#     * LA LOMA I
#     * LA RUEDA
#     * POLILLAS DE ZACOALCO
#     * LAS MARAVILLAS
#     * SAN SEBASTIAN DEL OESTE
#     * AMAPAS - CONCHAS CHINAS
#     * EL DUQUE
#     * VISTA DEL REY
#     * NATUREZZA
#     * PEDREGAL DEL BOSQUE
#     * PASEO DEL BOSQUE
#     * RECIENTE AMANECER
#     * EL RINCON SECRETO
#     * LOS CIPRECES
#     * DIANA
#     * LOS AGRILLOS
#     * FRACCIONAMIENTO COTO DEL REY
#     * EL GALLITO
#     * CRUZ DE LOS SINARQUISTAS (CLUB CINEGETICO)
#     * EL PORVENIR 2
#     * EL TULE
#     * XELJ
#     * LA ESTRELLA
#     * IPAZOLTIC
#     * VALLE VERDE
#     * PASEO DE LOS CAZOS
#     * OJO DE AGUA DEL PICACHO
#     * INQUILINOS GUZMANENSES (19 DE SEPTIEMBRE)
#     * AGUILOTE CENTRO
#     * VILLAS DE CALDERON
#     * LA COLMENA
#     * PLATANAR
#     * 1 DE AGOSTO
#     * TASINAXTLA
#     * BARRANCA DE SANTA CLARA
#     * CNOP
#     * TOTOLIMIXPA
#     * VILLAS DEL PRADO
#     * LA FRONTERA
#     * VENADEROS
#     * HIPODROMO
#     * UNIDAD DEPORTIVA
#     * LUIS DONALDO COLOSIO (POTRERO DE LA MULA)
#     * JARDINES DE LA CAÑADA
#     * EL REMOLINO
#     * SUMMS RESIDENCIAL
#     * LAS AVES
#     * ANA LUCIA
#     * LA LADERA
#     * FONHAPO PONIENTE
#     * OBRERO
#     * COLOMITOS
#     * LOS LLANOS
#     * EL CIELO COUNTRY CLUB
#     * JARDINES DE SAN GONZALO
#     * CTM LOS ORGANOS
#     * LOS CEREZOS
#     * EL ZAPOTE II
#     * VILLAS DEL TEPEYAC
#     * ALTARA
#     * ARRAYANES HABITAT
#     * VIGUSA
#     * CEIBAS
#     * VILLAS DE LA PRIMAVERA
#     * COLORINES
#     * REAL CANTABRIA
#     * VALLE DEL FORTIN
#     * SAN ALBERTO
#     * MANUEL MARTINEZ VALADEZ
#     * CUATRO CAMINOS
#     * LA MERCED
#     * PUERTA DE CHIRIPA (LA PASCUALA)
#     * LA MAJADA DE SAN ISIDRO
#     * CASA REAL SANGRE DE CRISTO
#     * SANTA BARBARA (ESTACION CASTRO)
#     * LOMAS DE LOURDES
#     * CORRAL DE PIEDRA
#     * CAÑADAS DEL SOL
#     * HUERTA DE LAS FLORES
#     * EL CONDIRO
#     * EL RANCHO NUEVO
#     * GUADALAJARA
#     * LAS BUGAMBILIAS
#     * CHILA
#     * VILLAS DEL ROBLE
#     * VILLAS DE SAN DIEGO
#     * PUERTA DE LA VEGA
#     * PUERTA DEL LAGO
#     * EL PERRAL
#     * EL PINO
#     * SAN CRISTOBAL
#     * VISTAS DE LA FLORESTA
#     * LA PITAYERA
#     * ALAMO
#     * LA MORITA
#     * LIRIOS
#     * SANGRE DE CRISTO
#     * LOMAS DE ZAPOTLAN
#     * LOMAS DEL RIO
#     * POZO SANTO
#     * MIRADORES DE TONAYA LA AVIACION
#     * EL HUEHUETON
#     * ASUNCION
#     * FCO SILVA ROMERO (MADERERA)
#     * EL ALAMBRE
#     * COLINAS DE LA BAHIA
#     * LOS MEDANOS
#     * POBRE
#     * TRAPICHE
#     * MONTE CALVARIO
#     * MAGISTERIAL 2
#     * LOS AGUACATES
#     * LA CAJITA DEL AGUA
#     * LOMAS DE LA ARBOLEDA
#     * SAUZ DE LOS MARQUEZ
#     * TUXPAN DE BOLAÑOS
#     * BARRIO GUADALUPANO
#     * LAS PILAS
#     * AGUA CALIENTE NUEVA
#     * PADRE JOSE ISABEL FLORES
#     * JUAN PABLO
#     * BOSQUE DE LOS LAGOS
#     * LOS GALAVICES
#     * TLAYOLAN
#     * CHANCHAME
#     * LA MILAGROSA
#     * PASEOS DEL REAL
#     * PASO DE GANADO
#     * INDUSTRIAL
#     * LOS BRISEÑO
#     * APULCO
#     * VALLE DE MAJAHUAS
#     * LAZARO CARDENAS (LA NANCY)
#     * LA HERMITA
#     * EL TULE NORTE
#     * LUCIO BLANCO
#     * PBLO SAN MARTIN DE LAS FLORES DE ABAJO
#     * PRADERAS DE ORIENTE ( EL  MIRADOR)
#     * ABADIA SAN MARTIN
#     * POTRERO EL ZALATE
#     * EL PIRULITO
#     * RIVERAS DE LA UNIDAD
#     * LOMAS DE SAN JAVIER
#     * MIRADOR DEL ROSAL
#     * CERRITO II
#     * ALTEA
#     * SENDEROS DE TLAQUEPAQUE
#     * PRADOS DEL MAGUEY
#     * SAUCES DE ENMEDIO
#     * OJO ZARCO DE FUENTES
#     * PARQUE DE LOS FRESNOS
#     * LA SAGRADA FAMILIA
#     * LOMAS DE SAN ALFONSO
#     * RINCONADA SAN ANTONIO
#     * VILLA DE ORNELAS
#     * NUEVO REFUGIO
#     * EL LOPEÑO
#     * EL GUAYABAL
#     * MIRANDILLAS
#     * ESTANZUELA
#     * TRAPICHE DE LABRA
#     * EL BARRO
#     * EPENCHE CHICO
#     * RANCHO QUEMADO
#     * LOMA ALTA
#     * MARIA AUXILIADORA
#     * AGUILOTE
#     * 20 DE NOVIEMBRE 2a ETAPA
#     * NUEVO JERUSALEM
#     * TEOCALLI
#     * EL PASTOR (COLINAS DEL SUR)
#     * LAS MORITAS
#     * LA EJIDAL
#     * EL TEPEHUAJE
#     * RINCON DE LUISA
#     * IPEVI (COAJINQUE)
#     * PRADOS DE LA MONTAÑA
#     * EL CANAL
#     * SAN SIMON (JULIAN MEDINA)
#     * PASEO DEL MIRADOR
#     * POPULAR DON BOSCO
#     * PREDIO LA ESPERANZA
#     * JARDINES DE AHUALULCO
#     * EVERARDO TOPETE
#     * VERDE
#     * QUINTAS DE LA SOBERANA
#     * EL PRADO
#     * COLINAS EL CENTINELA
#     * MONTEVERDE
#     * JARDINES EL SANTO
#     * DE SAN ANTONIO
#     * JAZMINEZ DEL VERDE
#     * QUINTA SANTA ANITA
#     * JARDINES DEL CAPULIN
#     * PONTEVEDRA
#     * LAS ESCUELAS
#     * GUAMUCHIL
#     * TLAQUEPAQUE PUEBLITO
#     * SOTO PARK
#     * PRADOS DEL VALLE
#     * RINCONADA DE LOS VAZQUEZ
#     * LAS BRISAS
#     * HUEJOTITLAN
#     * LOS PILARES
#     * VILLA MORELOS
#     * LAS CUEVAS
#     * EL VERDE 2DA SECCION
#     * MOLINO VIEJO
#     * EL NOGAL
#     * EL OCOTITO
#     * LA MOJONERA
#     * LA PEÑITA
#     * SANTA CRUZ DE LOS ESPINOS
#     * EL CAMPITO
#     * LA VENTA DE MOCHITILTIC
#     * LAS BOCAS
#     * TLALCOSAHUA
#     * BELLISSIMO
#     * REAL DE SAN IGNACIO
#     * SAN REMO
#     * ALVIENTO
#     * PLACITA DEL SOL
#     * REAL ALTEÑO
#     * PRADOS DEL ROBLE
#     * JARDINEZ DE LA PAZ
#     * REAL DE HACIENDAS
#     * VALLE LA CAMPANA
#     * MAL PASITO
#     * LOMAS DE SAN FRANCISCO
#     * VIRGEN DE GUADALUPE
#     * SAN NICOLAS DE ACUÑA
#     * LA MESITA
#     * LOMAS DE SAN SEBASTIAN
#     * LA TEJA 2
#     * VISTA OCEANO
#     * LIENZO CHARRO
#     * HUIXTLA
#     * SEVILLA
#     * SALVADOR ALCARAZ
#     * LA UNION
#     * PUERTO DE LUNA
#     * SAN JUAN DE POTREROS
#     * AYAMONTE
#     * LA FORJA
#     * LA ALBERCA
#     * VISTAS  DEL VALLE
#     * PUERTA LAS LOMAS
#     * VILLAS DE SANTIAGO
#     * MIRADOR DEL SUR
#     * LOS AGAVES
#     * SANTO TORIBIO ROMO
#     * SAN JOSE DEL CALICHE
#     * ESTACION SAN JUAN (SANTA MARIA DEL CAMBIO)
#     * PRADERAS DEL CARMEN
#     * LAS LIMAS
#     * JOAQUIN AMARO (LOS SAUCES)
#     * SANTA MARIA DE LA HUERTA
#     * EL ARCO
#     * VILLAS DEL TONIL
#     * LAS PILASTRAS
#     * JARDINES DEL SALTO
#     * LA CONDESA
#     * SAN MIGUEL DE HIDALGO
#     * EL HUEHUETON 2
#     * MARBELLA
#     * COLINA UNIVERSITARIA
#     * PRIMAVERA DE VALLARTA
#     * HUERTAS DEL ZAMORANO
#     * VICTORIANO HUERTA
#     * NOSTIC
#     * LOMA DE LOS REYES
#     * LAS LIEBRES 2DA SECCION
#     * EL REPARO
#     * EL MEZQUITITO
#     * LA GALLINITA
#     * LA LIMONESTA
#     * EL NUEVO POBLADO
#     * COLOSIO
#     * SAN JUAN DIEGO
#     * LOS CORRALES (VILLA DE GUADALUPE)
#     * EL CHOME
#     * NUEVO SANTIAGO
#     * SAN FELIPE DE HIJAR
#     * LA COYOTERA
#     * EL CUIS
#     * JARDINES DE ATOYAC NORTE
#     * LAS LANZAS
#     * FRACC HACIENDA CAPRICHO
#     * LA AVIACION
#     * EL TINACO DE AGUA
#     * ANOCA
#     * LINDA VISTA
#     * LOS OCOTES
#     * ESPERANZA DE SAN ANDRES
#     * POTRERO DE GOMEZ
#     * EL OLIVO
#     * EL VOLANTIN
#     * SAN BUENAVENTURA
#     * PUERTA DE PERICOS
#     * JUAN GIL PRECIADO 2
#     * ORILLA DE LA CERCA
#     * COFRADIA DEL ROSARIO
#     * VALLE MAGNO
#     * ACUEDUCTO SAN MIGUEL
#     * JARDINES DEL RAICERO
#     * PINAR DEL LAGO
#     * VILLA OLIMPICA
#     * LAS CHARANDAS
#     * MOISES QUEZADA
#     * CHULUAPAN
#     * MIRTOS
#     * LAS TEJERIAS
#     * EL AMAQUEÑO
#     * HABITACIONAL SAN ANDRES
#     * EL SALTILLO
#     * SIERRA DE QUILA
#     * SAN ANTONIO DE LA GARZA
#     * PUERTA AQUA
#     * OJO ZARCO
#     * RESIDENCIAL ARBOLEDAS
#     * RESERVA REAL
#     * REAL DE BOSQUE
#     * JARDIN DEL REAL
#     * CORDERO
#     * LAS VARITAS
#     * VISTAS DEL VALLE 1
#     * FRACC CAMINO REAL
#     * PEÑA AMARILLA
#     * VISTAS DE SAN AGUSTIN II
#     * SABINERA
#     * EJIDO LA UNION
#     * LA AURORA SUR
#     * REAL DE LAS LOMAS
#     * DORADOS DE VILLA I
#     * PARQUES ALDAMA
#     * LA FLORESTA NORTE
#     * VILLAS DE HUIXTLA
#     * ARBOLEDAS DE LA ESTACION
#     * VILLA CORAL
#     * EL PARQUE
#     * LOS ESPINOS
#     * EL PASTOR
#     * REAL SAN BERNARDO
#     * LA LAGUNITA
#     * LAGO REAL
#     * ALCAZAR ORIENTE
#     * EL INSTITUTO
#     * LA PAREJA (LOS CUATES)
#     * CALERITA
#     * FLORESTA SAN ANDRES 2
#     * LEONES
#     * CERRO DEL REFUGIO
#     * EL MALUCO
#     * YUYO
#     * VILLAS DE ALCALA
#     * LA LAGUNILLA
#     * LAS PALMITAS
#     * RESIDENCIAL DEL COUNTRY
#     * DOCTORES
#     * LAS VICTORIAS
#     * MISION SAN FRANCISCO
#     * NOGALERA
#     * SAN SABASTIAN
#     * CERRITO DE BUENOS AIRES
#     * LA HUERTA 2
#     * VALLE DE LA AMISTAD
#     * LA LOMA RESIDENCIAL
#     * VISTA DEL PARAISO
#     * RINCON DE TAPALPA
#     * VISTA DE LA BAHIA
#     * LOMAS DE SAN GABRIEL
#     * LA CONSTANCIA

# %%
# municipios
print("- Nombre de los municipios:")
for i in df.municipio.unique():
    print("    * "+i)

#Clave de municipio
print("Clave de los municipios:")
for i in df.clave_mun.unique():
    print("    * "+str(int(i)))
# Out:
# - Nombre de los municipios:
#     * GUADALAJARA
#     * ZAPOPAN
#     * SAN PEDRO TLAQUEPAQUE
#     * TONALA
#     * TLAJOMULCO DE ZUÑIGA
#     * JUCHITLAN
#     * MAZAMITLA
#     * COLOTLAN
#     * TUXPAN
#     * IXTLAHUACAN DE LOS MEMBRILLOS
#     * ZAPOTLANEJO
#     * TAPALPA
#     * EL SALTO
#     * MAGDALENA
#     * ATOTONILCO EL ALTO
#     * JUANACATLAN
#     * LA BARCA
#     * TALA
#     * VILLA CORONA
#     * PONCITLAN
#     * AMECA
#     * JOCOTEPEC
#     * AMATITAN
#     * ARANDAS
#     * SAN MIGUEL EL ALTO
#     * JALOSTOTITLAN
#     * IXTLAHUACAN DEL RIO
#     * YAHUALICA DE GONZALEZ GALLO
#     * TEPATITLAN DE MORELOS
#     * ACATIC
#     * MEXTICACAN
#     * CAÑADAS DE OBREGON
#     * CUQUIO
#     * SAN IGNACIO CERRO GORDO
#     * JESUS MARIA
#     * VALLE DE GUADALUPE
#     * LAGOS DE MORENO
#     * SAN JUAN DE LOS LAGOS
#     * UNION DE SAN ANTONIO
#     * VILLA HIDALGO
#     * OJUELOS DE JALISCO
#     * TEOCALTICHE
#     * ENCARNACION DE DIAZ
#     * OCOTLAN
#     * AYOTLAN
#     * JAMAY
#     * TOTOTLAN
#     * ZAPOTLAN DEL REY
#     * DEGOLLADO
#     * CHAPALA
#     * ACATLAN DE JUAREZ
#     * TEOCUITATLAN DE CORONA
#     * ZAPOTLAN EL GRANDE
#     * ZACOALCO DE TORRES
#     * ZAPOTILTIC
#     * SAYULA
#     * TAMAZULA DE GORDIANO
#     * GOMEZ FARIAS
#     * ZAPOTITLAN DE VADILLO
#     * AMACUECA
#     * ATOYAC
#     * AUTLAN DE NAVARRO
#     * EL GRULLO
#     * AYUTLA
#     * TECOLOTLAN
#     * EJUTLA
#     * TOLIMAN
#     * PUERTO VALLARTA
#     * TOMATLAN
#     * CABO CORRIENTES
#     * MASCOTA
#     * COCULA
#     * SAN MARTIN HIDALGO
#     * ATENGO
#     * TALPA DE ALLENDE
#     * TEUCHITLAN
#     * ETZATLAN
#     * EL ARENAL
#     * HOSTOTIPAQUILLO
#     * SAN JUANITO DE ESCOBEDO
#     * TEQUILA
#     * AHUALULCO DE MERCADO
#     * SAN MARCOS
#     * HUEJUCAR
#     * MEZQUITIC
#     * TOTATICHE
#     * VILLA GUERRERO
#     * SAN MARTIN DE BOLAÑOS
#     * SANTA MARIA DE LOS ANGELES
#     * BOLAÑOS
#     * LA HUERTA
#     * VILLA PURIFICACION
#     * CUAUTITLAN DE GARCIA BARRAGAN
#     * CIHUATLAN
#     * CASIMIRO CASTILLO
#     * TENAMAXTLAN
#     * MIXTLAN
#     * TIZAPAN EL ALTO
#     * ATEMAJAC DE BRIZUELA
#     * PIHUAMO
#     * SAN GABRIEL
#     * UNION DE TULA
#     * SAN CRISTOBAL DE LA BARRANCA
#     * HUEJUQUILLA EL ALTO
#     * SAN JULIAN
#     * SAN DIEGO DE ALEJANDRIA
#     * TUXCUECA
#     * TECALITLAN
#     * JILOTLAN DE LOS DOLORES
#     * TONILA
#     * CHIQUILISTLAN
#     * SAN SEBASTIAN DEL OESTE
#     * VALLE DE JUAREZ
#     * QUITUPAN
#     * TECHALUTA DE MONTENEGRO
#     * TUXCACUESCO
#     * GUACHINANGO
#     * CHIMALTITAN
#     * CONCEPCION DE BUENOS AIRES
#     * ATENGUILLO
#     * TONAYA
#     * LA MANZANILLA DE LA PAZ
#     * EL LIMON
#     * CUAUTLA
#     * N.D.
#     * SANTA MARIA DEL ORO
# Clave de los municipios:
#     * 39
#     * 120
#     * 98
#     * 101
#     * 97
#     * 52
#     * 59
#     * 25
#     * 108
#     * 44
#     * 124
#     * 86
#     * 70
#     * 55
#     * 13
#     * 51
#     * 18
#     * 83
#     * 114
#     * 66
#     * 6
#     * 50
#     * 5
#     * 8
#     * 78
#     * 46
#     * 45
#     * 118
#     * 93
#     * 1
#     * 60
#     * 117
#     * 29
#     * 125
#     * 48
#     * 111
#     * 53
#     * 73
#     * 109
#     * 116
#     * 64
#     * 91
#     * 35
#     * 63
#     * 16
#     * 47
#     * 105
#     * 123
#     * 33
#     * 30
#     * 2
#     * 92
#     * 23
#     * 119
#     * 121
#     * 82
#     * 85
#     * 79
#     * 122
#     * 4
#     * 14
#     * 15
#     * 37
#     * 17
#     * 88
#     * 34
#     * 99
#     * 67
#     * 100
#     * 20
#     * 58
#     * 24
#     * 77
#     * 11
#     * 84
#     * 95
#     * 36
#     * 9
#     * 40
#     * 7
#     * 94
#     * 3
#     * 75
#     * 41
#     * 61
#     * 104
#     * 115
#     * 76
#     * 81
#     * 19
#     * 43
#     * 68
#     * 27
#     * 22
#     * 21
#     * 90
#     * 62
#     * 96
#     * 10
#     * 65
#     * 113
#     * 110
#     * 71
#     * 42
#     * 74
#     * 72
#     * 107
#     * 87
#     * 49
#     * 103
#     * 32
#     * 80
#     * 112
#     * 69
#     * 89
#     * 106
#     * 38
#     * 31
#     * 26
#     * 12
#     * 102
#     * 57
#     * 54
#     * 28
#     * 999
#     * 56

# %%
#Existe un ND en las filas
print("- El rango de fechas va desde {0} hasta {1}.".format(df.hora.unique().min(), df.hora.unique().max()))
# Out:
# - El rango de fechas va desde 00:00 hasta N.D..

# %%
# Que segemento fue afectado
print("- Los bienes afectados son:", df.bien_afectado.unique())
# Out:
# - Los bienes afectados son: ['La libertad y la seguridad sexual' 'La vida y la integridad corporal'
#  'El patrimonio' 'La familia']

# %%
# Zona geografica en Jalisco
print("- La zona geografica del dataset:", df.zona_geografica.unique())
# Out:
# - La zona geografica del dataset: ['AMG' 'Interior']

# %% [markdown]
# ## 3. Missing Values

# %%
df.isna().sum()
# Out:
# fecha                  0
# delito                 0
# x                  10949
# y                  10949
# colonia                0
# municipio              0
# clave_mun              0
# hora                   0
# bien_afectado          0
# zona_geografica        0
# dtype: int64

# %% [markdown]
# Únicamente se observan valores nulos en las variables de las coordenadas, sin embargo aunque no se muestren valores nulos en las demás variables se logró identificar las siguientes observaciones:
#  * En la variable colonia existen unos *NO DISPONIBLES*
#  + En la variable hora se encuentra *N.D.*
#  + Y en la varibale clave_mun hay un número *999* que no corresponde a ningún municipio

# %% [markdown]
# ## 4. Limpieza de datos

# %%
# Seleccionar el filtro únicamente con los municipios y borrar el 999 que es NO DISPONIBLE
df.drop(df[df['clave_mun'] == 999].index, inplace=True)

#Ahora borrar de la variable colonia el NO DISPONIBLE
df.drop(df[df['colonia'] == 'NO DISPONIBLE'].index, inplace=True)

# Y finalmente borrar el ND de la variable hora
df.drop(df[df['hora'] == 'N.D.'].index, inplace=True)

# %%
df.head(3)
# Out:
#          fecha                 delito           x          y  \
# 38  14/10/2019  Abuso sexual infantil -103.299889  20.641185
# 77  30/10/2019  Abuso sexual infantil -103.273903  20.647750
# 84  01/11/2019  Abuso sexual infantil -103.360971  20.627276
#
#                colonia              municipio  clave_mun   hora  \
# 38  JARDINES DE LA PAZ  SAN PEDRO TLAQUEPAQUE         98  02:00
# 77         INSURGENTES            GUADALAJARA         39  03:00
# 84          ECHEVERRIA            GUADALAJARA         39  15:00
#
#                         bien_afectado zona_geografica
# 38  La libertad y la seguridad sexual             AMG
# 77  La libertad y la seguridad sexual             AMG
# 84  La libertad y la seguridad sexual             AMG

# %% [markdown]
# Ahora el dataset depurado tiene 219,083 registros con las mismas variables ya mencionadas

# %%
print("- El rango de fechas va desde {0} hasta {1}.".format(df.hora.unique().min(), df.hora.unique().max()))
# Out:
# - El rango de fechas va desde 00:00 hasta 23:59.

# %% [markdown]
# Se ha depurado el rango de horas

# %%
# Se ha convertido la fecha en formato internacional ISO
df['fecha'] = pd.to_datetime(df['fecha'])
pd.to_datetime(df.fecha, format = '%Y/%m/%d')
# Out:
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '14/10/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '30/10/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '14/11/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '19/11/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '20/11/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '28/11/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '15/12/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '16/12/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '20/12/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '24/12/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '26/12/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '27/12/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '28/12/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '20/04/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '28/05/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '20/06/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '22/07/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '18/09/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '19/09/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '16/10/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '27/11/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '25/12/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '15/11/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '23/11/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '26/11/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '15/10/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '17/10/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '25/10/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '22/11/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '30/12/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '21/08/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '26/08/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '17/09/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '13/12/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '13/10/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '18/10/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '19/10/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '20/10/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '21/10/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '23/10/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '24/10/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '26/10/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '27/10/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '28/10/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '29/10/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '31/10/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '13/11/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '16/11/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '17/11/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '18/11/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '21/11/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '24/11/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '25/11/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '29/11/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '30/11/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '14/12/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '17/12/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '18/12/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '21/12/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '22/12/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '23/12/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '29/12/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '31/12/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '16/06/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '17/06/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '18/06/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '22/06/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '29/06/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '13/08/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '14/08/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '16/08/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '17/08/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '22/08/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '23/08/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '24/08/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '28/08/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '30/08/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '31/08/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '13/09/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '14/09/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '15/09/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '16/09/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '20/09/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '21/09/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '22/09/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '23/09/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '24/09/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '25/09/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '26/09/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '27/09/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '28/09/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '29/09/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '30/09/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '25/08/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '19/12/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '22/10/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '14/01/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '15/01/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '21/01/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '24/01/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '25/01/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '26/01/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '28/01/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '30/01/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '31/01/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '18/02/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '26/02/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '27/02/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '13/03/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '14/03/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '22/03/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '25/03/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '27/03/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '31/03/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '15/04/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '17/04/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '22/04/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '23/04/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '24/04/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '29/04/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '30/04/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '16/05/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '21/05/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '25/05/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '27/05/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '29/05/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '30/05/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '13/06/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '14/06/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '15/06/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '19/06/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '21/06/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '23/06/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '24/06/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '25/06/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '26/06/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '27/06/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '28/06/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '30/06/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '15/07/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '24/07/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '26/07/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '29/07/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '15/08/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '18/08/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '19/08/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '20/08/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '27/08/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '16/07/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '29/08/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '19/07/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '16/01/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '22/02/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '31/05/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '29/01/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '14/02/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '21/02/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '25/02/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '23/03/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '30/03/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '25/04/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '27/04/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '24/05/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '17/07/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '23/07/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '31/07/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '17/01/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '18/01/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '23/01/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '13/02/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '15/02/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# ...
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '15/04/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '21/04/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '14/05/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '15/05/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '21/05/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '29/05/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '26/06/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '29/07/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '13/08/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '14/08/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '28/08/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '18/09/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '30/09/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '26/11/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '22/12/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '25/12/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '18/12/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '27/12/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '26/02/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '18/05/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '20/07/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '22/02/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '15/02/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '13/01/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '27/01/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '30/01/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '23/01/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '17/01/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '26/01/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '20/02/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '28/02/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '13/02/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '24/02/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '16/01/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '25/01/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '18/01/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '23/02/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '27/02/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '14/02/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '24/01/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '16/02/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '19/01/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '17/02/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '14/01/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '31/01/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '18/02/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '21/02/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '26/02/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '29/01/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '15/01/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '22/01/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '28/01/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '19/02/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '20/01/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '25/02/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\eduri\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '21/01/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# 38       2019-10-14
# 77       2019-10-30
# 84       2019-01-11
# 87       2019-04-11
# 88       2019-04-11
#             ...
# 293965   2023-11-02
# 293966   2023-12-02
# 293967   2023-02-15
# 293968   2023-02-16
# 293969   2023-01-02
# Name: fecha, Length: 219083, dtype: datetime64[ns]

# %%
df.head(3)
# Out:
#         fecha                 delito           x          y  \
# 38 2019-10-14  Abuso sexual infantil -103.299889  20.641185
# 77 2019-10-30  Abuso sexual infantil -103.273903  20.647750
# 84 2019-01-11  Abuso sexual infantil -103.360971  20.627276
#
#                colonia              municipio  clave_mun   hora  \
# 38  JARDINES DE LA PAZ  SAN PEDRO TLAQUEPAQUE         98  02:00
# 77         INSURGENTES            GUADALAJARA         39  03:00
# 84          ECHEVERRIA            GUADALAJARA         39  15:00
#
#                         bien_afectado zona_geografica
# 38  La libertad y la seguridad sexual             AMG
# 77  La libertad y la seguridad sexual             AMG
# 84  La libertad y la seguridad sexual             AMG

# %% [markdown]
# Ahora que se tienen los datos limpios con formato de fecha ISO y sin ningun nulo y vacios en los datos, se procede a realizar la visualización de los datos con el objetivo de encontrar información útil e indispensable que permita identificar zonas afectadas, tipos de delito e aumento, los bienes afectados y caracteristicas importantes para la elaboración de modelos que posterioremente midan la relación causa-efecto entre factores y el crimen en el Estado de Jalisco

# %%
#Exportación de la base de datos depurada y limpia
df.to_csv('data_delitos_clean.csv')

# %% [markdown]
# ## 5. Visualización de los datos

# %%
delitos_tiempo = df.pivot_table(index=["fecha"], values=["delito"],aggfunc='count').reset_index()
delitos_tiempo
# Out:
#           fecha  delito
# 0    2019-01-01      37
# 1    2019-01-02     122
# 2    2019-01-03     119
# 3    2019-01-04     108
# 4    2019-01-05      54
# ...         ...     ...
# 1515 2023-10-02     188
# 1516 2023-11-01     161
# 1517 2023-11-02      87
# 1518 2023-12-01     159
# 1519 2023-12-02      91
#
# [1520 rows x 2 columns]

# %%
alt.Chart(delitos_tiempo).mark_line(interpolate='basis').encode(
    alt.X("fecha:T",title="Periodo"),
    alt.Y('delito:Q', title="Número de delitos")
).properties(
    title="Frecuencia de delitos realizados en Jalisco durante 2019-2023"
).properties(width=500, height=300)
# Out:
# alt.Chart(...)

# %% [markdown]
# Se puede observar una tendencia a la alza del incremento de delitos durante el segundo semestre del año 2019 y el primer semestre del 2020 (pandemia de COVID-19), despues vuelve una ligera reducción de delitos durante el resto del 2020, 2021 y 2022.
#
#   **Nota**: La libreria realiza una interpolación en los próximos meses**

# %%
alt.Chart(delitos_tiempo).transform_density(
    'delito',
    as_=['delito', 'density'],
).mark_area().encode(
    alt.X("delito:Q",title="Delito"),
    alt.Y('density:Q', title="Probabilidad")
).properties(title="Distribución de densidad de delitos")
# Out:
# alt.Chart(...)

# %% [markdown]
# La probabilidad en la tendencia de la información se encuentra entre los 180 y 200 delitos.

# %%
tipo_delito = df.groupby(['delito']).size().reset_index(name='frecuencia')
tipo_delito
# Out:
#                            delito  frecuencia
# 0           Abuso sexual infantil        2496
# 1                     Feminicidio         172
# 2                Homicidio doloso        5005
# 3                Lesiones dolosas       22889
# 4                   Robo a bancos          73
# 5             Robo a carga pesada        1030
# 6          Robo a cuentahabientes        1462
# 7         Robo a int de vehiculos       10704
# 8                  Robo a negocio       30701
# 9                  Robo a persona       36180
# 10  Robo a vehiculos particulares       39874
# 11           Robo casa habitacion       13543
# 12             Robo de autopartes        6822
# 13            Robo de motocicleta       10426
# 14                      Violacion        1263
# 15             Violencia familiar       36443

# %%
# Gráfica autodescriptiva: 
alt.Chart(tipo_delito).mark_bar().encode(
    alt.X("delito:N", sort= '-y',title="Tipo de Delito", bin=False),
    alt.Y('frecuencia:Q', title="Carpetas de investigación"),
    alt.Color('delito', legend=None)
).properties(
    title="Gráfico de barras de número de delitos por tipo de delito (2019-2023)"
)
# Out:
# alt.Chart(...)

# %% [markdown]
# En el top 5 de los delitos cometidos se encuentra el **robo a vehiculos particulares**, **violencia familiar**, el robo a personas y negocios y las lesiones dolosas.

# %%
bien_afectado = df.groupby(['bien_afectado']).size().reset_index(name='frecuencia')
bien_afectado
# Out:
#                        bien_afectado  frecuencia
# 0                      El patrimonio      150815
# 1                         La familia       36443
# 2  La libertad y la seguridad sexual        3759
# 3   La vida y la integridad corporal       28066

# %%
base=alt.Chart(bien_afectado).encode(
theta=alt.Theta('frecuencia:Q', stack=True),
color=alt.Color('bien_afectado:N', legend=None)
)
pie = base.mark_arc(outerRadius=120)
text = base.mark_text(radius=180, size=13).encode(text='bien_afectado:N')
pie + text
# Out:
# alt.LayerChart(...)

# %% [markdown]
# El patrimonio de los Jalisciences se vio fuertemente afectado por los delitos cometidos durante el periodo analizado por el robo de sus pertenencias y enseguida llama la atención la violencia familiar que se presenta en el estado.

# %%
zona = df.pivot_table(index=["delito","zona_geografica"], values=["fecha"],aggfunc='count').reset_index()
zona
# Out:
#                            delito zona_geografica  fecha
# 0           Abuso sexual infantil             AMG   1045
# 1           Abuso sexual infantil        Interior   1451
# 2                     Feminicidio             AMG    135
# 3                     Feminicidio        Interior     37
# 4                Homicidio doloso             AMG   4242
# 5                Homicidio doloso        Interior    763
# 6                Lesiones dolosas             AMG  15763
# 7                Lesiones dolosas        Interior   7126
# 8                   Robo a bancos             AMG     68
# 9                   Robo a bancos        Interior      5
# 10            Robo a carga pesada             AMG    990
# 11            Robo a carga pesada        Interior     40
# 12         Robo a cuentahabientes             AMG   1366
# 13         Robo a cuentahabientes        Interior     96
# 14        Robo a int de vehiculos             AMG  10120
# 15        Robo a int de vehiculos        Interior    584
# 16                 Robo a negocio             AMG  28950
# 17                 Robo a negocio        Interior   1751
# 18                 Robo a persona             AMG  34854
# 19                 Robo a persona        Interior   1326
# 20  Robo a vehiculos particulares             AMG  37082
# 21  Robo a vehiculos particulares        Interior   2792
# 22           Robo casa habitacion             AMG  10516
# 23           Robo casa habitacion        Interior   3027
# 24             Robo de autopartes             AMG   6593
# 25             Robo de autopartes        Interior    229
# 26            Robo de motocicleta             AMG   8196
# 27            Robo de motocicleta        Interior   2230
# 28                      Violacion             AMG    996
# 29                      Violacion        Interior    267
# 30             Violencia familiar             AMG  27668
# 31             Violencia familiar        Interior   8775

# %%
plot_1 = alt.Chart(zona).mark_point().encode(
    alt.X("delito:N",title="Tipos de delito"),
    alt.Y("fecha:Q",scale=alt.Scale(type="log"), title="Número delitos"),
    alt.Color("zona_geografica:N",title="Zona geografica"),
    alt.Shape("zona_geografica:N"),
    tooltip=["delito","zona_geografica","fecha"]
).properties(title="Relación del número de delitos y tipo de delitos por zona geografica")

plot_1
# Out:
# alt.Chart(...)

# %% [markdown]
# Podemos observar que la mayoria de los delitos se han cometido en la zona metropolitana de Guadalajara por encima de los otros municipios, sin embargo llama la atención que el delito de **abuso sexual infantil** el resto de los municipios se encuentrán por encima del área metropolitana de Guadalajara (una posible causa se puede deber a que en cierto municipios todavía existe el matrimonio de adultos con menores de edad).

# %%
top_municipio = df.pivot_table(index=["delito","municipio"], values=["fecha"],aggfunc='count').reset_index()
top_municipio
# Out:
#                      delito              municipio  fecha
# 0     Abuso sexual infantil                 ACATIC      4
# 1     Abuso sexual infantil      ACATLAN DE JUAREZ     10
# 2     Abuso sexual infantil   AHUALULCO DE MERCADO      9
# 3     Abuso sexual infantil               AMACUECA      1
# 4     Abuso sexual infantil               AMATITAN      3
# ...                     ...                    ...    ...
# 1189     Violencia familiar             ZAPOTILTIC     94
# 1190     Violencia familiar  ZAPOTITLAN DE VADILLO      2
# 1191     Violencia familiar       ZAPOTLAN DEL REY     15
# 1192     Violencia familiar     ZAPOTLAN EL GRANDE    262
# 1193     Violencia familiar            ZAPOTLANEJO    195
#
# [1194 rows x 3 columns]

# %%
alt.Chart(
    top_municipio,
).mark_bar().encode(
    x=alt.X('municipio:N', sort='-y'),
    y=alt.Y('fecha:Q', title="Número de delitos"),
    color=alt.Color('fecha:Q', title='delitos')

).transform_window(
    rank='rank(fecha)',
    sort=[alt.SortField('fecha', order='descending')]
).transform_filter(
    (alt.datum.rank < 100)
)
# Out:
# alt.Chart(...)

# %% [markdown]
# Y efectivamente observamos que Guadalajara es el municipio con mayor índice de delitos, seguido el municipio de Zapopan, Tonala y Tlajomulco, practicamente municipios del área metropolitana de Guadalajara.
# Esto debido a la mayor cantidad de habitantes que existe en comparación con el resto de la población de Jalisco

# %%
df_2 = df.copy(deep=True)
df_2.index = pd.DatetimeIndex(df_2.fecha)

# %%
days = ['Lunes','Martes','Miercoles',  'Jueves', 'Viernes', 'Sabado', 'Domingo']
df.groupby([df_2.index.dayofweek]).size().plot(kind='barh')
plt.ylabel('Dias de la semana')
plt.yticks(np.arange(7), days)
plt.xlabel('Número de delitos')
plt.title('Número de delitos por día de la semana')
plt.show()

# %% [markdown]
# Frecuentemente los delitos ocurrieron a inicios de la semana (martes es el principal dia de la semana con mayor delitos).

# %%
horario = df.pivot_table(index=["hora"], values=["fecha"],aggfunc='count').reset_index()
horario
# Out:
#        hora  fecha
# 0     00:00   3071
# 1     00:01    113
# 2     00:02     27
# 3     00:03     30
# 4     00:04      8
# ...     ...    ...
# 1433  23:55    102
# 1434  23:56     13
# 1435  23:57      9
# 1436  23:58     19
# 1437  23:59     26
#
# [1438 rows x 2 columns]

# %%
alt.Chart(horario).mark_bar().encode(
    alt.X("hora:N", sort= '-y',title="Horario de asalto", bin=False),
    alt.Y('fecha:Q', title="Número de carpetas"),
    alt.Color('fecha', legend=None)
).properties(
    title="Gráfico de barras de frecuencia de delitos por horario del día"
).transform_window(
    rank='rank(fecha)',
    sort=[alt.SortField('fecha', order='descending')]
).transform_filter(
    (alt.datum.rank < 20)
)
# Out:
# alt.Chart(...)

# %% [markdown]
# Y el horario de la madrugada presento la mayoria de los delitos, siendo los horarios por la noche cuando se presentaron los delitos, es decir, la probabilidad de menor influencia de personas en la calle los delincuentes proceden a realizar el crimen por las ventajas que se presentan en la oscuridad.

# %% [markdown]
# #### *Hasta el momento se ha revisado de manera general los tipos de delitos pero que sucede en cada uno de los municipios y colonias del Estado*

# %%
delito_count_date = df_2.pivot_table('fecha', aggfunc=np.size, columns='delito', 
                                    index=df_2.index.date, fill_value=0)
delito_count_date.index = pd.DatetimeIndex(delito_count_date.index)
plot = delito_count_date.rolling(365).sum().plot(figsize=(15, 25), 
                  subplots=True, layout=(-1, 3), sharex=False, sharey=False)

# %% [markdown]
# Si existe una reducción en los delitos que son ocasioados a bienes patrimoniales como el robo a vehículos, homocidios, feminicidios (que es una premisa de las que argumente el Gobernador de Jalisco, Enrique Alfaro), sin embargo en temas de **Violación, Violencia Familiar, Abuso sexual a menores, lesiones dolosas**, son delitos cometidos hacia la persona y su integridad. Estos han presentado un aumento generalizo en los últimos meses generando preocupación por parte de los ciudadanos jalisciences.

# %% [markdown]
# La intención es revisar dos de los delitos cometidos hacia la integridad de la persona como lo son la  Violencia Familiar y la Violación, identificando las zonas mayormente perjudicadas por estos crimenes.

# %% [markdown]
# #### <span style="color:blue"> Delitos de Violencia Familiar por municipio y colonias del Estado de Jalisco </span>

# %%
from folium import plugins
data_j = df[df['delito']=='Violencia familiar']
jalisco_map = folium.Map(location=[20.34, -102.91],zoom_start =11)
data_loc= data_j[['y','x']].values
data_loc =data_loc.tolist()
hm = plugins.HeatMap(data_loc)
hm.add_to(jalisco_map)
jalisco_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e3c5f6eb50c52b2302d4152818101446 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e3c5f6eb50c52b2302d4152818101446&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e3c5f6eb50c52b2302d4152818101446 = L.map(
#                 &quot;map_e3c5f6eb50c52b2302d4152818101446&quot;,
#                 {
#                     center: [20.34, -102.91],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7bc8534ef5808dee20dbb1a4e67be3fc = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_e3c5f6eb50c52b2302d4152818101446);
#
#
#             var heat_map_647a38d700ea89c4ac2447983aa8f0e0 = L.heatLayer(
#                 [[20.56859065, -103.2763475], [20.65159933, -103.2850442], [20.6971425, -103.3647965], [20.58937165, -103.33802], [20.47329449, -103.2759927], [20.59504858, -103.2433898], [20.67630011, -103.3264021], [20.73867772, -103.4172187], [20.47718412, -103.4426645], [20.74790457, -103.3335188], [20.6342002, -103.2615654], [20.74790457, -103.3335188], [20.72058467, -103.3717907], [20.65316821, -103.2805792], [20.73088904, -103.3280182], [20.64756894, -103.2723278], [20.702272, -103.3364737], [20.53069551, -103.4263513], [20.49850053, -103.2025784], [20.45691417, -103.4388363], [20.73643374, -103.4187785], [20.63885493, -103.226365], [20.76823972, -103.4197251], [20.66348021, -103.4476087], [20.63572324, -103.237166], [20.6627759, -103.199008], [20.58834256, -103.4239941], [20.61845667, -103.0630432], [20.48221882, -103.4083532], [20.65185139, -103.2270382], [20.65988435, -103.2776755], [20.46148392, -103.4286011], [20.74267936, -103.3967327], [20.64033726, -103.2963671], [20.62577521, -103.200101], [20.59433813, -103.2312918], [20.65004184, -103.2550997], [20.66301805, -103.2115053], [20.59710887, -103.353631], [20.72740277, -103.4288966], [20.62556087, -103.2701742], [20.74554856, -103.3364831], [20.46233602, -103.4287873], [21.1814021, -102.8908231], [20.7467176, -103.3462364], [20.76460536, -103.4451374], [20.48477756, -103.4072604], [20.63152787, -103.3926386], [20.50851242, -103.3610339], [20.85179867, -103.4266089], [20.72906055, -103.3194784], [20.67603398, -103.2940095], [20.76565896, -103.446769], [20.52426394, -103.3593173], [20.69877513, -103.2822956], [20.66952952, -103.2447997], [20.64077256, -103.4082155], [20.71027845, -103.364795], [20.56808335, -103.3722257], [20.65761848, -103.2698734], [20.67530089, -103.3127621], [20.50630274, -103.3962763], [20.61861, -103.3709176], [20.76388285, -103.3426476], [20.75482085, -103.3406743], [20.58731051, -103.3520191], [20.57111799, -103.1562291], [20.7347475, -103.3089203], [20.76338427, -103.3463048], [20.61612094, -103.3448489], [20.56496605, -103.3888985], [20.6807449, -103.4072039], [20.61749955, -103.3053236], [20.71816318, -103.3698196], [20.75373588, -103.3976822], [20.69293817, -103.2905729], [20.6388523, -103.4453157], [20.63669015, -103.3187083], [20.65909653, -103.3229708], [20.64828561, -103.4030317], [20.727965, -103.360401], [20.69346507, -103.4399118], [20.70767072, -103.2961352], [20.6994924, -103.2849177], [20.61789696, -103.3620726], [20.63875286, -103.4563813], [20.76180715, -103.3326654], [20.64249098, -103.4391081], [20.65499807, -103.2539299], [20.66776146, -103.2109641], [20.62780885, -103.4650128], [20.62768764, -103.4534511], [20.61144103, -103.4528625], [20.67426049, -103.2419235], [20.66218879, -103.2835813], [20.5896085, -103.2334088], [20.52666916, -103.1739645], [20.58870641, -103.266002], [20.76318343, -103.4477259], [20.58937957, -103.2331044], [20.52593539, -103.3689388], [20.64816265, -103.3331762], [20.62541278, -103.4647681], [20.69447761, -103.3124372], [20.64192794, -103.4659843], [20.6972723, -103.3646896], [20.69048917, -103.2844999], [20.66675022, -103.2717508], [20.73660709, -103.4307904], [20.74229274, -103.3490933], [20.60569019, -103.4353001], [20.62879534, -103.262145], [20.5013145, -103.3585134], [20.6247313, -103.071239], [20.48282808, -103.398967], [20.64971592, -103.2895024], [20.69773871, -103.2652867], [20.62639508, -103.1963134], [20.5352692, -103.4806771], [20.63412115, -103.2671797], [20.521746, -103.3732155], [20.63071859, -103.3690081], [20.72607547, -103.3687843], [20.46870509, -103.4417337], [20.62975516, -103.3394978], [20.60122657, -103.4341848], [20.6085492, -103.2962795], [20.65145282, -103.3026397], [20.60705506, -103.4373873], [20.519159, -103.3860871], [20.76530666, -103.3555421], [20.4988054, -103.202759], [20.63681182, -103.4534836], [20.69189113, -103.2713011], [20.7070

# %% [markdown]
# El delito de violencia familiar es mostrado a través de este mapa de calor detectando que la AMG es abarcada en su totalidad por dicho crimen

# %% [markdown]
# #####  <span style="color:blue"> Delitos de Violación por municipio y colonia del Estado de Jalisco </span>

# %%
data_j = df[df['delito']=='Violacion']
jalisco_map = folium.Map(location=[20.34, -102.91],zoom_start =11)
data_loc= data_j[['y','x']].values
data_loc =data_loc.tolist()
hm = plugins.HeatMap(data_loc)
hm.add_to(jalisco_map)
jalisco_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7aa770f5ff3ace9cd000d7d8f2754527 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7aa770f5ff3ace9cd000d7d8f2754527&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7aa770f5ff3ace9cd000d7d8f2754527 = L.map(
#                 &quot;map_7aa770f5ff3ace9cd000d7d8f2754527&quot;,
#                 {
#                     center: [20.34, -102.91],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_19f929e117b1823771463e72460f2dc2 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_7aa770f5ff3ace9cd000d7d8f2754527);
#
#
#             var heat_map_283e7cf92226ebbbea80d5f581f72e6d = L.heatLayer(
#                 [[20.69208241, -103.3177309], [20.75407007, -103.4250391], [20.69566103, -103.4550381], [20.67847876, -103.3737359], [20.72685478, -103.3397695], [20.65216393, -103.2550371], [20.63384857, -103.3497089], [20.69694921, -103.3581114], [20.76380896, -103.3670927], [20.60735101, -103.3358775], [20.67445695, -103.3140436], [20.85469043, -103.4305312], [20.63022525, -103.4423039], [20.65325082, -103.3296553], [20.63000415, -103.3616176], [20.62567389, -103.2915122], [20.42422493, -103.1892021], [20.6136814, -103.3686993], [20.61738864, -103.3571487], [20.6190743, -103.3916307], [20.6637742, -103.4163548], [20.69885647, -103.3618611], [20.65622777, -103.4307135], [20.49057797, -103.4142672], [20.65665709, -103.3305053], [20.75286931, -103.3977489], [20.67219316, -103.3786477], [20.63011131, -103.3916726], [20.68492954, -103.3869852], [20.53889649, -103.4331558], [20.67233047, -103.368598], [20.70030004, -103.3541459], [20.72748934, -103.3923127], [20.64174389, -103.3172901], [20.66961017, -103.3272391], [20.6567664, -103.429432], [20.64113737, -103.4037013], [20.81103771, -103.4958688], [20.67787429, -103.4044886], [20.44641356, -103.4323485], [21.44564928, -102.5714924], [21.2320681, -102.3441498], [20.3656194, -102.769817], [20.82291956, -102.7656891], [21.24030891, -102.3338832], [20.30513188, -103.200456], [19.6987553, -103.4763124], [20.21954947, -103.9437], [19.75575966, -104.3837208], [20.63672985, -105.2320566], [20.85334756, -103.4515707], [20.6194768, -103.4589787], [20.66279296, -103.2895944], [20.64407679, -103.3999753], [20.59710786, -103.4742856], [20.70510466, -103.3471808], [20.57178543, -103.3334722], [20.75791093, -103.3891677], [20.45534109, -103.2512704], [20.50825492, -103.4060132], [20.67831054, -103.3407061], [20.65898142, -103.2933664], [20.41882418, -103.5984166], [20.6528825, -103.2617945], [20.70745564, -103.4120036], [20.74632561, -103.4188197], [20.63722905, -103.4526637], [20.74503865, -103.3398016], [20.65921813, -103.3560572], [20.6065736, -103.3705684], [20.61459182, -103.3906594], [20.61363691, -103.380137], [20.68808465, -103.3488603], [20.80097904, -103.4926052], [20.52641901, -103.3565622], [20.68121436, -103.3351927], [20.74077255, -103.4080069], [20.72936585, -103.3388203], [20.75794133, -103.3550682], [20.69271066, -103.3385737], [20.66579009, -103.3557889], [20.67058218, -103.3442279], [20.65011937, -103.3234533], [20.6920008, -103.3107565], [20.67454993, -103.3482854], [20.67806295, -103.3533224], [20.54576492, -103.336804], [20.67359289, -103.3032863], [20.73778307, -103.3555709], [20.68820786, -103.2854932], [20.57198859, -103.312639], [20.54387529, -102.5099171], [20.59755056, -103.3428326], [20.62437826, -103.4370475], [20.67059764, -103.2894779], [20.67645344, -103.2479354], [20.7284328, -103.4161154], [20.47359942, -103.4170221], [20.62932454, -103.2519298], [20.64570998, -103.382022], [20.63153449, -103.4442385], [20.70593176, -103.4509786], [20.59159358, -103.3361157], [20.62976849, -103.4477589], [20.69577098, -103.3135776], [20.61490699, -103.2788143], [20.67531359, -103.2736043], [20.73011781, -103.4215518], [20.56683593, -103.3552699], [20.6811126, -103.3484344], [20.72021344, -103.391871], [20.67469041, -103.2697348], [20.648833, -105.2416418], [20.72721898, -103.3981918], [20.64424453, -103.3480492], [20.45747829, -103.4191076], [20.66353112, -103.2702702], [20.51622057, -103.3648037], [20.66607259, -103.3159355], [20.61276352, -103.4553154], [20.50067516, -103.3650903], [20.6966737, -103.1786574], [20.45596598, -103.4292223], [20.67498646, -103.2746493], [20.68862883, -103.4365535], [20.64630119, -103.2778481], [20.73976095, -103.3489334], [20.59414026, -103.3473505], [20.63134788, -103.4306046], [20.73733352, -103.39802], [20.53223264, -103.4283156], [20.7688031, -103.3650702], [20.69604643, -103.373264], [20.75224044, -103.3846085]

# %% [markdown]
# El mismo caso de la violación es denotada en el área metropolitana de Guadalajara, dando hincapie a que la mayor parte de los delitos se cometen en áreas urbanas y alrededores

# %% [markdown]
# ##### <span style="color:blue"> Delitos de Abuso sexual infantil por municipio y colonia del Estado de Jalisco </span>

# %%
data_j = df[df['delito']=='Abuso sexual infantil']
jalisco_map = folium.Map(location=[20.34, -102.91],zoom_start =11)
data_loc= data_j[['y','x']].values
data_loc =data_loc.tolist()
hm = plugins.HeatMap(data_loc)
hm.add_to(jalisco_map)
jalisco_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0a308fb986053b6c36f0ddfc6b5281b2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0a308fb986053b6c36f0ddfc6b5281b2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0a308fb986053b6c36f0ddfc6b5281b2 = L.map(
#                 &quot;map_0a308fb986053b6c36f0ddfc6b5281b2&quot;,
#                 {
#                     center: [20.34, -102.91],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_14323feee27f948e533a25c83a160d90 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_0a308fb986053b6c36f0ddfc6b5281b2);
#
#
#             var heat_map_217541e3c3e8dd6146f16714662c439c = L.heatLayer(
#                 [[20.64118495, -103.299889], [20.6477497, -103.2739033], [20.62727559, -103.3609708], [20.59137943, -103.2719031], [20.68194078, -103.346776], [20.57441486, -103.4401272], [20.64826881, -103.4417074], [20.46912341, -103.289236], [20.56902558, -103.1506637], [20.54863753, -103.3406847], [20.61116583, -103.4465557], [20.72219251, -103.323343], [20.62735577, -103.4822321], [20.65611255, -103.3770832], [20.71818252, -103.3699538], [20.62157653, -103.4620623], [20.6472879, -103.2561004], [20.70985629, -103.4504203], [20.68858791, -103.2943803], [20.80784133, -103.464437], [20.51795957, -103.2330657], [20.68148647, -103.2614881], [20.50422607, -103.3670555], [20.5646985, -103.3873283], [20.62277273, -103.2650726], [20.66283008, -103.3109844], [20.66976179, -103.2699394], [20.57071062, -103.3376757], [20.47496341, -103.4477821], [20.61882644, -103.2481735], [20.61655001, -103.3800643], [20.74661127, -103.3483309], [20.68904615, -103.3658335], [20.85179867, -103.4266089], [20.57794633, -103.3325612], [20.60609898, -103.3359199], [20.7178987, -103.3113292], [20.60413181, -103.3119088], [20.44706663, -103.4308423], [20.62036884, -103.3550222], [20.5976147, -103.2894172], [20.68952582, -103.249014], [20.61175442, -103.2384685], [20.67824629, -103.243039], [20.70784741, -103.2952461], [20.71816318, -103.3698196], [20.62247777, -103.4557491], [20.64860813, -103.3134085], [21.36124877, -101.8767513], [21.23966373, -102.339556], [20.79335398, -102.765325], [20.8190204, -102.7394372], [21.44083587, -102.3514101], [21.35583091, -101.9052553], [21.23192949, -102.3364994], [21.24258592, -102.3288737], [20.29723106, -102.7108403], [20.27884427, -102.5486999], [20.34211643, -102.7541153], [20.43036702, -102.4950334], [20.21431666, -104.1600137], [19.42518389, -103.4099916], [19.66590731, -103.2456281], [19.67870454, -103.4688655], [19.87447957, -103.5393044], [19.70364917, -103.455047], [19.65369515, -103.709752], [19.79225403, -103.4687634], [19.68379811, -103.4760044], [19.76808811, -104.3553321], [19.95791492, -104.2731482], [20.65772089, -105.2074582], [20.61344758, -105.2305667], [20.60160931, -105.2258844], [20.63532208, -105.226757], [20.70866345, -105.211924], [20.63563734, -105.2048408], [22.62506399, -103.8967318], [20.4079922, -103.7728446], [19.22925974, -104.7012096], [20.64124972, -103.3954485], [20.66546434, -103.2119727], [20.67963088, -103.3467166], [20.64623033, -103.2993339], [20.63031111, -103.2731191], [20.659364, -103.2864006], [20.75498968, -103.3440152], [20.73160096, -103.3364243], [20.66620891, -103.1984697], [20.73305197, -103.4029038], [20.76562965, -103.3896333], [20.57928328, -103.4301017], [20.45726907, -103.4224346], [20.4565825, -103.4259694], [20.68018963, -103.4383293], [20.50661715, -103.3689344], [20.45925455, -103.4288252], [20.67901436, -103.3429788], [20.45783698, -103.4327235], [20.62313723, -103.2546294], [20.51426134, -103.3808193], [20.74364437, -103.4053075], [20.65869049, -103.3882965], [20.60019546, -103.2503339], [20.68440945, -103.2784204], [20.49351962, -103.4055072], [20.47289332, -103.4518037], [20.75041455, -103.3333953], [20.59181825, -103.4287167], [20.53421589, -103.3884421], [20.62644329, -103.2726014], [20.61111349, -103.2952532], [20.75233394, -103.3591973], [20.6024292, -103.3319304], [20.63813732, -103.3004507], [20.60879018, -103.3458519], [20.7602348, -103.436356], [20.69048816, -103.272335], [20.49930475, -103.3619319], [20.6274589, -103.1961185], [20.73324856, -103.3947868], [20.61174855, -103.3485614], [20.65644472, -103.3337539], [20.60976804, -103.3398425], [20.79409901, -103.4684947], [20.56872887, -103.3359416], [20.66953291, -103.3390593], [20.60771103, -103.1734325], [20.67420427, -103.2514932], [20.76835837, -103.3300645], [20.67236182, -103.4199516], [20.67164017, -103.2498334], [20.60899312, -103.4259789], [20.67425161, -103.2561

# %% [markdown]
# Anteriormente analizamos que el delito de **abuso sexual infantil** es uno de los menos cometidos en comparativa con los demás pero tiene una fuerte influencia en los municipios que no son el AMG y es un delito que va en aumento por lo que se debe considerar y poner atención

# %%
delitos_zmg = df[(df['delito']=='Violencia familiar') & (df['zona_geografica']=='AMG') & (df['municipio']=='ZAPOPAN')]
#delitos_zmg

# %% [markdown]
# ##### <span style="color:blue"> Delitos de violencia familiar en las colonias de Zapopan </span>

# %%
delito_zapopan = delitos_zmg.pivot_table(index=["colonia"], values=["fecha"],aggfunc='count').reset_index()
#delito_zapopan

# %%
alt.Chart(
    delito_zapopan,
).mark_bar().encode(
    x=alt.X('colonia:N', sort='-y'),
    y=alt.Y('fecha:Q', title="Número de delitos"),
    color=alt.Color('fecha:Q', title="delitos")
).transform_window(
    rank='rank(fecha)',
    sort=[alt.SortField('fecha', order='descending')]
).transform_filter(
    (alt.datum.rank < 20)
)
# Out:
# alt.Chart(...)

# %% [markdown]
# Observamos que en el municipio de Zapopan las colonias con mayor registro de delitos en violencia familiar: son Valle de los Molinos (Que se encuentra al norte y afueras de la ciudad), Miramar y Constitución

# %% [markdown]
# ##### <span style="color:blue"> Delitos de violaciones en las colonias de Guadalajara </span>

# %%
delitos_zmg = df[(df['delito']=='Violacion') & (df['zona_geografica']=='AMG') & (df['municipio']=='GUADALAJARA')]
#delitos_zmg

# %%
delito_gdl = delitos_zmg.pivot_table(index=["colonia"], values=["fecha"],aggfunc='count').reset_index()
#delito_gdl

# %%
alt.Chart(
    delito_gdl,
).mark_bar().encode(
    x=alt.X('colonia:N', sort='-y'),
    y=alt.Y('fecha:Q', title="Número de delitos"),
    color=alt.Color('fecha:Q', title="delitos")

).transform_window(
    rank='rank(fecha)',
    sort=[alt.SortField('fecha', order='descending')]
).transform_filter(
    (alt.datum.rank < 20)
)
# Out:
# alt.Chart(...)

# %% [markdown]
# Las colonias que presentan mayor índice de violaciones a personasson: Oblatos, Zona Centro y Rancho Nuevo.

# %% [markdown]
# #### <span style="color:blue"> Delitos de abuso sexual infantil en los municipios fuera de la AMG </span>

# %%
delitos_int = df[(df['delito']=='Abuso sexual infantil') & (df['zona_geografica']=='Interior')]
#delitos_int

# %%
delito_int = delitos_int.pivot_table(index=["municipio"], values=["fecha"],aggfunc='count').reset_index()
#delito_int

# %%
alt.Chart(
    delito_int,
).mark_rect().encode(
    x=alt.X('municipio:N', sort='-y'),
    y=alt.Y('fecha:Q', title="Número de delitos"),
    color=alt.Color('fecha:Q', title="delitos")

).transform_window(
    rank='rank(fecha)',
    sort=[alt.SortField('fecha', order='descending')]
).transform_filter(
    (alt.datum.rank < 30)
)
# Out:
# alt.Chart(...)

# %% [markdown]
# Puerto Vallarta arrebasa a los demás municipios fuera de la AMG. Se necesita implementar medidas para la prevención de este delito en dicho municipio.

# %% [markdown]
# ## 6. Comentarios Finales

# %% [markdown]
# <div style="text-align: justify">  El presente trabajo tuvo como objetivo promover una sugerencia como punto de partida para la recopilación, organización, limpieza, procesamiento, sistematización y visualización de los datos; permitiendo la identificación, mapeo y georreferenciación de los delitos (Violencia familiar, robo a vehículos, robo a personas, abuso sexual infantil, entre otros) y cuestionarse si realemte existe un impacto positivo por reducir la inseguridad en el estado, debido a que la estrategia de seguridad carece de políticas, de planeación sobre el modelo policial y de reflexión ante el avance del crimen organizado en el control del territorio jalisciense.
# Lo realmente grato de todos estos estudios es saber que estos temas son del interés de  grandes investigadores. Y, aunque algunos nos son determinantes para definir las causas  delictivas, sí que son una buena herramienta para tomar decisiones y distribuir de forma  adecuada los ingresos que se destinan al combate del crimen con base a programas integrales para prevenir, atender y sancionar a quienes cometen delitos. Academicos insisten en la idea de programas académicos que ofrezcan un cambio de perspectiva, para generar constructores de paz y seguridad que coordinen lo público, lo privado, la academia, con mirada histórica, internacionalista e integral. <div>

# %% [markdown]
# ## 7. Referencias

# %% [markdown]
# + https://www.udg.mx/es/noticia/politica-de-seguridad-en-jalisco-entre-la-violencia-endemica-y-la-sumision-al-crimen#:~:text=En%20el%20periodo%20de%202015,primer%20lugar%20en%20el%20pa%C3%ADs.
#
# + BECKER, Gary. S. 1968. Crime and Punishment: An Economic Approach. Journal of Political Economy. Reprinted in Chicago Studies in Political Economy, edited by G.J.Stigler. Chicago and London: The University of Chicago Press, 1988.
#
# + https://iieg.gob.mx/ns/page_id=22174#:~:text=De%20acuerdo%20con%20el%20Secretariado,Fiscal%C3%ADas%20Generales%20de%20las%20entidades
#
# + Rock, Paul (1997), “Sociological Theories of Crime”, en Mike Maguire, Rod Morgan y Robert Reiner (eds.), The Oxford Handbook of Criminology, Oxford, Oxford University Press.
#
# + Jessop, Bob (2006), “Political Economy”, en S. Bryan Turner (ed.), The Cambridge Disctionary of Sociology, Nueva York, Cambridge University Press.
